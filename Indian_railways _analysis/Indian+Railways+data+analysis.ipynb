# %%
import pandas as pd

# %%
indianrailways = pd.read_csv("D:\python files\pandas exercise\indianrailways2.csv")
indianrailways.head()
# Out:
#   Train_No       train_Name  islno station_Code     Station_Name Arrival_time  \
# 0  '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR       '00:00:00'
# 1  '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR         '01:10:00'
# 2  '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM     '05:10:00'
# 3  '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN     '11:10:00'
# 4  '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN      '16:42:00'
#
#   Departing_time  Distance Source_StationCode source_Station_Name  \
# 0     '22:50:00'         0               BBS      BHUBANESWAR
# 1     '01:12:00'       166               BBS      BHUBANESWAR
# 2     '05:30:00'       443               BBS      BHUBANESWAR
# 3     '11:20:00'       793               BBS      BHUBANESWAR
# 4     '16:52:00'      1169               BBS      BHUBANESWAR
#
#   Destination_station_Code Destination_Station_Name
# 0                     BNC           BANGALORE CANT
# ...

# %%
indianrailways.shape
# Out:
# (69006, 12)

# %%
in1 = indianrailways.columns.tolist()
in2 = []
for i in in1:
    in2.append(i.lower())
in2
# Out:
# ['train_no',
#  'train_name',
#  'islno',
#  'station_code',
#  'station_name',
#  'arrival_time',
#  'departing_time',
#  'distance',
#  'source_stationcode',
#  'source_station_name',
#  'destination_station_code',
#  'destination_station_name']

# %%
indianrailways.columns = in2
indianrailways.head(2)
# Out:
#   train_no       train_name  islno station_code     station_name arrival_time  \
# 0  '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR       '00:00:00'
# 1  '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR         '01:10:00'
#
#   departing_time  distance source_stationcode source_station_name  \
# 0     '22:50:00'         0               BBS      BHUBANESWAR
# 1     '01:12:00'       166               BBS      BHUBANESWAR
#
#   destination_station_code destination_station_name
# 0                     BNC           BANGALORE CANT
# 1                     BNC           BANGALORE CANT

# %%
indianrailways.train_name = indianrailways.train_name.str.replace('EXPRESS','EXP')
indianrailways.station_name = indianrailways.station_name.str.replace('JUNCTION','JN')
#indianrailways.train_name = indianrailways.train_name.str.replace('EX','EXP')
indianrailways.train_name = indianrailways.train_name.str.replace('PASS','PASSENGER')

# %%
indianrailways.dtypes
# Out:
# train_no                    object
# train_name                  object
# islno                        int64
# station_code                object
# station_name                object
# arrival_time                object
# departing_time              object
# distance                     int64
# source_stationcode          object
# source_station_name         object
# destination_station_code    object
# destination_station_name    object
# dtype: object

# %%
indianrailways[indianrailways.distance == max(indianrailways.distance)]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 35457  '15905'  DBRG  VIVEK EXP     62         DBRG  DIBRUGARH
# 35519  '15906'      VIVEK EXP       62         CAPE  KANYAKUMARI
#
#       arrival_time departing_time  distance source_stationcode  \
# 35457   '07:15:00'     '00:00:00'      4273               CAPE
# 35519   '09:50:00'     '00:00:00'      4273               DBRG
#
#       source_station_name destination_station_code destination_station_name
# 35457     KANYAKUMARI                         DBRG          BANGALORE CANT
# 35519     DIBRUGARH                           CAPE          BANGALORE CANT

# %%
# we have to drop the tables based on a condition
indianrailways.sort_values('distance').head(100)
# Out:
#       train_no            train_name  islno station_code     station_name  \
# 0      '00851'       BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 61256  '51029'       BB BJP FAST PAS      1         CSTM  MUMBAI CST
# 61287  '51030'       BJP BB FAST PAS      1         BJP   BIJAPUR
# 23495  '13049'       AMRITSAR EXP         1         HWH   HOWRAH JN
# 23477  '13044'           RXL HWH EXP      1         RXL   RAXAUL JN
# 23459  '13043'           HWH RXL EXP      1         HWH   HOWRAH JN
# 23448  '13028'       KAVI GURU EXP        1         AZ    AZIMGANJ JN
# 23437  '13027'       KAVI GURU EXP        1         HWH   HOWRAH JN
# 23412  '13026'       BPL HOWRAH EXP       1         BPL   BHOPAL  JN
# 3066   '11031'       SUR BIJAPUR EXP      1         SUR   SOLAPUR JN
# 23387  '13025'           HWH BPL EXP      1         HWH   HOWRAH JN
# 23354  '13024'       GAYA HWH EXPRES      1         GAYA  GAYA JN
# 23606  '13050'           ASR HWH EXP      1         ASR   AMRITSAR JN
# ...

# %%
indianrailways.isnull().sum()
# Out:
# train_no                    0
# train_name                  0
# islno                       0
# station_code                0
# station_name                0
# arrival_time                0
# departing_time              0
# distance                    0
# source_stationcode          0
# source_station_name         0
# destination_station_code    0
# destination_station_name    0
# dtype: int64

# %%
import numpy as np
indianrailways[indianrailways.distance == 0] = np.nan

# %%
indianrailways.sort_values('distance').head(100)
# Out:
#       train_no            train_name  islno station_code     station_name  \
# 17797  '12737'       GOUTAMI EXP        2.0         CCT   KAKINADA TOWN
# 62646  '53178'  LGL SDAH PASSENGER      2.0         KRP   KRISHNAPUR
# 45011  '17644'       CIRCAR EXP         2.0         CCT   KAKINADA TOWN
# 63874  '56138'  ONR UAM PASSENGERR      2.0         WEL   WELLINGTON
# 37443  '16235'       MYSORE  EXP        2.0         TME   TUTI MELUR
# 40628  '16611'       TN CBE LINK EXP    2.0         TME   TUTI MELUR
# 62573  '53172'  LGL SDAH PASSENGER      2.0         KRP   KRISHNAPUR
# 64932  '57258'       TIRUPATI PSGR      2.0         CCT   KAKINADA TOWN
# 68747  '59812'  HALDIGHATI PASSENGER    2.0         IDH   IDGAH AGRA JN
# 8861   '12195'       AF AII INTERCIT    2.0         IDH   IDGAH AGRA JN
# 65338  '57305'  KCGGNT PASSENGER        2.0         MXT   MALAKPET
# 1342   '07703'       PUSHKARAM SPL      2.0         CCT   KAKINADA TOWN
# ...

# %%
indianrailways.isnull().sum()
# Out:
# train_no                    2814
# train_name                  2814
# islno                       2814
# station_code                2814
# station_name                2814
# arrival_time                2814
# departing_time              2814
# distance                    2814
# source_stationcode          2814
# source_station_name         2814
# destination_station_code    2814
# destination_station_name    2814
# dtype: int64

# %%
indianrailways = indianrailways.dropna(axis = 0,how = 'any')
indianrailways.shape
# Out:
# (66192, 12)

# %%
indianrailways.sort_values('distance',ascending = False).head(30)
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 35457  '15905'  DBRG  VIVEK EXP   62.0         DBRG  DIBRUGARH
# 35519  '15906'      VIVEK EXP     62.0         CAPE  KANYAKUMARI
# 35518  '15906'      VIVEK EXP     61.0         NCJ   NAGERCOIL JN
# 35456  '15905'  DBRG  VIVEK EXP   61.0         NTSK  NEW TINSUKIA JN
# 35517  '15906'      VIVEK EXP     60.0         TVC   TRIVANDRUM CNTL
# 35516  '15906'      VIVEK EXP     59.0         QLN   KOLLAM JN
# 35455  '15905'  DBRG  VIVEK EXP   60.0         MXN   MARIANI JN
# 35515  '15906'      VIVEK EXP     58.0         CNGR  CHENGANNUR
# 35514  '15906'      VIVEK EXP     57.0         TRVL  TIRUVALLA
# 35454  '15905'  DBRG  VIVEK EXP   59.0         FKG   FURKATING JN
# 35513  '15906'      VIVEK EXP     56.0         KTYM  KOTTAYAM
# 35453  '15905'  DBRG  VIVEK EXP   58.0         DMV   DIMAPUR
# 35512  '15906'      VIVEK EXP     55.0         ERN   ERNAKULAM TOWN
# ...

# %%
indianrailways[indianrailways.station_name.str.contains('NAGERCOIL')]
# Out:
#       train_no            train_name  islno station_code     station_name  \
# 15783  '12633'       KANYAKUMARI EXP   17.0         NCJ   NAGERCOIL JN
# 15786  '12634'       KANYAKUMARI EXP    2.0         NCJ   NAGERCOIL JN
# 15883  '12641'       TIRUKKURAL EXP     2.0         NCJ   NAGERCOIL JN
# 15934  '12642'       THIRUKKURAL EXP   26.0         NCJ   NAGERCOIL JN
# 16358  '12660'           GURUDEV EXP   45.0         NCJ   NAGERCOIL JN
# 16478  '12665'       KANNYAKUMARI EX   32.0         NCJ   NAGERCOIL JN
# 16481  '12666'       CAPE HOWRAH EXP    2.0         NCJ   NAGERCOIL JN
# 16524  '12667'       NAGERCOIL EXP     12.0         NCJ   NAGERCOIL JN
# 16884  '12689'       NAGERCOIL EXP     20.0         NCJ   NAGERCOIL JN
# 35397  '15905'       DBRG  VIVEK EXP    2.0         NCJ   NAGERCOIL JN
# 35518  '15906'           VIVEK EXP     61.0         NCJ   NAGERCOIL JN
# 36699  '16127'       MS GURUVAYUR EX   25.0         NCJ   NAGERCOIL JN
# ...

# %%
indianrailways.distance.sort_values()
# Out:
# 17797       2.0
# 62646       2.0
# 45011       2.0
# 63874       2.0
# 37443       2.0
# 40628       2.0
# 62573       2.0
# 64932       2.0
# 68747       2.0
# 8861        2.0
# 65338       2.0
# 1342        2.0
# 29409       2.0
# 55103       2.0
# 61109       2.0
# 47258       2.0
# 42907       2.0
# 25366       3.0
# 11361       3.0
# 7217        3.0
# 63152       3.0
# 21911       3.0
# 56107       3.0
# 16640       3.0
# 65651       3.0
# 37798       3.0
# 49470       3.0
# 16616       3.0
# 10119       3.0
# 7886        3.0
#           ...
# 1197     3650.0
# 35505    3661.0
# 38050    3666.0
# 37967    3682.0
# 38051    3700.0
# 35506    3711.0
# 37968    3714.0
# 38052    3715.0
# 35449    3717.0
# 35507    3758.0
# 35508    3761.0
# 35450    3774.0
# 35509    3816.0
# 35510    3893.0
# 35451    3898.0
# 35452    3930.0
# 35511    3947.0
# 35512    3964.0
# 35453    3967.0
# 35513    4026.0
# 35454    4037.0
# 35514    4052.0
# 35515    4061.0
# 35455    4075.0
# ...

# %%
indianrailways.train_name.value_counts().tail()
# Out:
# DGHA HWH DURONT    1
# INDORE DURONTO     1
# JU MBF LINK EXP    1
# MBF BGKT EXP       1
# PUNE DURONTO       1
# Name: train_name, dtype: int64

# %%
indianrailways.head(2)
# Out:
#   train_no       train_name  islno station_code     station_name arrival_time  \
# 1  '00851'  BNC SUVIDHA SPL    2.0         BAM   BRAHMAPUR         '01:10:00'
# 2  '00851'  BNC SUVIDHA SPL    3.0         VSKP  VISAKHAPATNAM     '05:10:00'
#
#   departing_time  distance source_stationcode source_station_name  \
# 1     '01:12:00'     166.0               BBS      BHUBANESWAR
# 2     '05:30:00'     443.0               BBS      BHUBANESWAR
#
#   destination_station_code destination_station_name
# 1                     BNC           BANGALORE CANT
# 2                     BNC           BANGALORE CANT

# %%
indianrailways.station_name.value_counts().tail()
# Out:
# FAQARSAR           1
# BALPUR HALT        1
# SHIRRAVDE          1
# PUNALUR            1
# AMBALE             1
# Name: station_name, dtype: int64

# %%
indianrailways.station_name.value_counts().tail(233)
# Out:
# PANSAR             2
# LALAWADI           1
# KORUKKUPET JN      1
# BAHMAN DIWANA      1
# MURLIGANJ          1
# DADHDEVI           1
# SUKNA              1
# SUWANSA            1
# BIRAPATTI          1
# KHANYAN            1
# AMB  ANDAURA       1
# DHULKOT            1
# BANKA              1
# LASERI             1
# PIRTHIGANJ         1
# KANKATHER          1
# JUGAUR             1
# SARKONI            1
# BARDHANA HALT      1
# KHAMGAON           1
# SILGHAT TOWN       1
# AREPALLI HALT      1
# KURLAS             1
# SENGOTTAI          1
# RAJAPUR            1
# JEONATHPUR         1
# PIPARSAND          1
# CHIHERU            1
# DIVITI PALLI       1
# MANANWALA          1
#                   ..
# CHHANDRAULI        1
# NEW BALARAMPUR     1
# MANYAMKONDA        1
# ISMAILA HARYANA    1
# GAUTAMSTHAN        1
# MADWARANI          1
# MAMAN              1
# KOLANUKONDA        1
# PALANI             1
# ALIGANJ            1
# SIKANDARPUR        1
# PATHRI             1
# ...

# %%
indianrailways[indianrailways.station_name.str.contains('MUNABAO ')]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 31454  '14889'  JU MBF LINK EXP    2.0         MBF   MUNABAO
#
#       arrival_time departing_time  distance source_stationcode  \
# 31454   '07:00:00'     '00:00:00'     325.0               BGKT
#
#       source_station_name destination_station_code destination_station_name
# 31454     BHAGAT KI KOTHI                     MBF           BANGALORE CANT

# %%
indianrailways[indianrailways.station_name.str.contains('KULWA ')]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 24241  '13131'  KOAA ANVT EXP    109.0         KLA   KULWA
#
#       arrival_time departing_time  distance source_stationcode  \
# 24241   '07:38:00'     '07:39:00'    1425.0               KOAA
#
#       source_station_name destination_station_code destination_station_name
# 24241     KOLKATA                             ANVT          BANGALORE CANT

# %%
indianrailways[indianrailways.station_name.str.contains('VELLORE')]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 2271   '11005'  PUDUCHERRY EXP    33.0         VLR   VELLORE CANT
# 2284   '11006'  CHALUKYA  EXP      7.0         VLR   VELLORE CANT
# 20094  '12867'  HWH PDY EXP       17.0         VT    VELLORE TOWN
# 20095  '12867'  HWH PDY EXP       18.0         VLR   VELLORE CANT
# 20101  '12868'  PDY HOWRAH EXP     4.0         VLR   VELLORE CANT
# 41337  '16779'  TPTY RMM EXP       4.0         VLR   VELLORE CANT
# 41374  '16780'  RMM TPTY EXP      19.0         VLR   VELLORE CANT
# 43991  '17407'      PAMANI EXP     5.0         VLR   VELLORE CANT
# 44020  '17408'  TIRUPATI EXPRES   15.0         VLR   VELLORE CANT
# 56718  '22603'  KGP VM SF EXP     17.0         VLR   VELLORE CANT
# 56725  '22604'  KHARAGPUR EXP      4.0         VLR   VELLORE CANT
# 56768  '22605'  PRR  VM  EXPRES   27.0         VLR   VELLORE CANT
# 56777  '22606'      PURULIA EXP    5.0         VLR   VELLORE CANT
#
# ...

# %%
indianrailways[indianrailways.station_Name.str.contains('TAMBARAM')]
# Out:
#       Train_No       train_Name  islno station_Code     Station_Name  \
# 1008   '06063'  TIRUNELVELI EXP      2         TBM   TAMBARAM
# 1033   '06064'  TEN CHENNAI EXP     13         TBM   TAMBARAM
# 2579   '11017'  LTT KARAIKAL EX     22         TBM   TAMBARAM
# 2600   '11018'  KIK LTT EXPRESS     11         TBM   TAMBARAM
# 4102   '11063'  MS SALEM EXP         2         TBM   TAMBARAM
# 4129   '11064'  SA CHENNAI EXP      13         TBM   TAMBARAM
# 15145  '12605'  PALLAVAN EXP         2         TBM   TAMBARAM
# 15167  '12606'  PALLAVAN EXP        11         TBM   TAMBARAM
# 15736  '12631'  NELLAI EXPRESS       2         TBM   TAMBARAM
# 15764  '12632'  NELLAI EXPRESS      14         TBM   TAMBARAM
# 15768  '12633'  KANYAKUMARI EXP      2         TBM   TAMBARAM
# 15800  '12634'  KANYAKUMARI EXP     16         TBM   TAMBARAM
# 15804  '12635'  VAIGAI EXP           2         TBM   TAMBARAM
# 15825  '12636'  VAIGAI EXP          11         TBM   TAMBARAM
# ...

# %%
indianrailways[indianrailways.Station_Name.str.contains('KULWA ')]
# Out:
# Empty DataFrame
# Columns: [Train_No, train_Name, islno, station_Code, Station_Name, Arrival_time, Departing_time, Distance, Source_StationCode, source_Station_Name, Destination_station_Code, Destination_Station_Name]
# Index: []

# %%
indianrailways.dtypes
# Out:
# Train_No                    object
# train_Name                  object
# islno                        int64
# station_Code                object
# Station_Name                object
# Arrival_time                object
# Departing_time              object
# Distance                     int64
# Source_StationCode          object
# source_Station_Name         object
# Destination_station_Code    object
# Destination_Station_Name    object
# dtype: object

# %%
trainsfromstation = pd.crosstab(indianrailways.Station_Name,indianrailways.train_Name)

# %%
trainsfromstation
# Out:
# train_Name       A P EXP          A P EXPRESS      A P SMPRK KRNTI  \
# Station_Name
# A N DEV NAGAR                  0                0                0
# ABHAIPUR                       0                0                0
# ABOHAR                         0                0                0
# ABU ROAD                       0                0                0
# ACHALDA                        0                0                0
# ACHHNERA JN                    0                0                0
# ADAS ROAD                      0                0                0
# ADAVALI                        0                0                0
# ADGAON BUZURG                  0                0                0
# ADHARTAL                       0                0                0
# ADHIKARI                       0                0                0
# ADI SAPTAGRAM                  0                0                0
# ADILABAD                       0                0                0
# ...

# %%
howrahtrains = indianrailways[indianrailways.station_name.str.contains('HOWRAH JN ')]
howrahtrains.train_name.nunique()
# Out:
# 114

# %%
shivajitrains = indianrailways[indianrailways.station_code.str.contains('CSTM')]
shivajitrains.train_name.nunique()
# Out:
# 47

# %%
chennaicentral = indianrailways[indianrailways.station_code.str.contains('MAS')]
chennaicentral.train_name.nunique()
# Out:
# 86

# %%
shivajitrains
# Out:
#       Train_No       train_Name  islno station_Code     Station_Name  \
# 57     '01153'  CSN CSTM T F SP     12         CSTM  MUMBAI CST
# 58     '01154'  CSTM CSN T F SP      1         CSTM  MUMBAI CST
# 217    '01711'  CSTM JBP SPL         1         CSTM  MUMBAI CST
# 271    '01714'  HBJ CSTM SUP SP     13         CSTM  MUMBAI CST
# 2081   '10103'  MANDOVI EXPRESS      1         CSTM  MUMBAI CST
# 2124   '10104'  MANDOVI EXPRESS     22         CSTM  MUMBAI CST
# 2125   '10111'  KONKAN KANYA EX      1         CSTM  MUMBAI CST
# 2166   '10112'  KONKAN KANYA EX     21         CSTM  MUMBAI CST
# 2316   '11007'  DECCAN EXPRESS       1         CSTM  MUMBAI CST
# 2338   '11008'  DECCAN EXPRESS      11         CSTM  MUMBAI CST
# 2339   '11009'  SINHAGAD EXP         1         CSTM  MUMBAI CST
# 2361   '11010'  SINHAGAD EXP        11         CSTM  MUMBAI CST
# 2622   '11019'  KONARK EXPRESS       1         CSTM  MUMBAI CST
# 2714   '11020'  KONARK EXPRESS      39         CSTM  MUMBAI CST
# ...

# %%
trainsfromstation.shape
# Out:
# (4337, 2187)

# %%
lowtrain = trainsfromstation.sum(axis = 1)

# %%
lowtrain.max()
# Out:
# 313

# %%
type(lowtrain)
# Out:
# pandas.core.series.Series

# %%
lowtrain.min()
# Out:
# 1

# %%
lowtrain.dtypes
# Out:
# dtype('int64')

# %%
lowtrain = pd.Series(lowtrain)

# %%
type(lowtrain)
# Out:
# pandas.core.series.Series

# %%
lowtrain.dtypes
# Out:
# dtype('int64')

# %%
lowtrain = dict(lowtrain)

# %%
sorted(lowtrain)
# Out:
# ['A N DEV NAGAR  ',
#  'ABHAIPUR       ',
#  'ABOHAR         ',
#  'ABU ROAD       ',
#  'ACHALDA        ',
#  'ACHHNERA JN    ',
#  'ADAS ROAD      ',
#  'ADAVALI        ',
#  'ADGAON BUZURG  ',
#  'ADHARTAL       ',
#  'ADHIKARI       ',
#  'ADI SAPTAGRAM  ',
#  'ADILABAD       ',
#  'ADINA          ',
#  'ADIPUR         ',
#  'ADITYAPUR      ',
#  'ADONI          ',
#  'ADRA JN        ',
#  'ADRSH NGR DELHI',
#  'ADUTURAI       ',
#  'AGASOD         ',
#  'AGOMONI        ',
#  'AGORI KHAS     ',
#  'AGRA CANTT     ',
#  'AGRA CITY      ',
#  'AGRA FORT      ',
#  'AHALYAPUR      ',
#  'AHERWADI       ',
#  'AHIRAN         ',
#  'AHMADGARH      ',
#  'AHMADNAGAR     ',
#  'AHMADPUR JN    ',
#  'AHMEDABAD JN   ',
#  'AHMEDABAD MG   ',
#  'AHRAURA ROAD   ',
#  'AISHBAGH       ',
#  'AIT            ',
#  'AITHAL         ',
#  'AJAKOLLU       ',
#  'AJANTI         ',
#  'AJARAKA        ',
#  'AJGAIN         ',
#  'AJJAMPUR       ',
#  'AJMER JN       ',
#  'AJNI           ',
# ...

# %%
indianrailways[indianrailways.train_name.str.contains('CHENNAI EXP')].shape
# Out:
# (607, 12)

# %%
chennaiexp = indianrailways[indianrailways.train_name.str.contains('CHENNAI EXP')]

# %%
chennaiexp.source_station_name.value_counts()
# Out:
# MANGALORE CNTL     70
# GURUVAYUR          47
# RAMESWARAM         43
# TRIVANDRUM CNTL    37
# NAGERCOIL JN       31
# ALLEPPEY           27
# TIRUCHENDUR        27
# AHMEDABAD JN       26
# VASCO DA GAMA      24
# DADAR              24
# CHENNAI EGMORE     22
# COIMBATORE JN      21
# HYDERABAD DECAN    20
# BHUBANESWAR        20
# TIRUCHCHIRAPALI    18
# BANGALORE CY JN    18
# HUBLI JN           17
# KARAIKAL           15
# ERNAKULAM JN       14
# TIRUNELVELI        14
# SAI P NILAYAM      14
# SALEM JN           13
# MADURAI JN         11
# MYSORE JN          11
# PUDUCHERRY         10
# YESVANTPUR JN       7
# METUR DAM           6
# Name: source_station_name, dtype: int64

# %%
chennaiexp[chennaiexp.source_station_name.str.contains('MANGALORE CNTL')].train_no.nunique()
# Out:
# 2

# %%
chennaiexp[chennaiexp.source_station_name.str.contains('VASCO DA GAMA')]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 43583  '17312'  VSG CHENNAI EXP    2.0         MAO   MADGAON
# 43584  '17312'  VSG CHENNAI EXP    3.0         SVM   SANVERDAM CHUCH
# 43585  '17312'  VSG CHENNAI EXP    4.0         QLM   KULEM
# 43586  '17312'  VSG CHENNAI EXP    5.0         CLR   CASTLE ROCK
# 43587  '17312'  VSG CHENNAI EXP    6.0         LD    LONDA JN
# 43588  '17312'  VSG CHENNAI EXP    7.0         DWR   DHARWAR
# 43589  '17312'  VSG CHENNAI EXP    8.0         UBL   HUBLI JN
# 43590  '17312'  VSG CHENNAI EXP    9.0         HVR   HAVERI
# 43591  '17312'  VSG CHENNAI EXP   10.0         RNR   RANIBENNUR
# 43592  '17312'  VSG CHENNAI EXP   11.0         HRR   HARIHAR
# 43593  '17312'  VSG CHENNAI EXP   12.0         DVG   DAVANGERE
# 43594  '17312'  VSG CHENNAI EXP   13.0         RRB   BIRUR JN
# 43595  '17312'  VSG CHENNAI EXP   14.0         ASK   ARSIKERE JN
# 43596  '17312'  VSG CHENNAI EXP   15.0         TTR   TIPTUR
# ...

# %%
chennaiexp
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 1022   '06064'  TEN CHENNAI EXP    2.0         MEJ   VANCHIMANIYACHI
# 1023   '06064'  TEN CHENNAI EXP    3.0         CVP   KOVILPATTI
# 1024   '06064'  TEN CHENNAI EXP    4.0         SRT   SATUR
# 1025   '06064'  TEN CHENNAI EXP    5.0         VPT   VIRUDUNAGAR JN
# 1026   '06064'  TEN CHENNAI EXP    6.0         MDU   MADURAI JN
# 1027   '06064'  TEN CHENNAI EXP    7.0         KQN   KODAIKANAL ROAD
# 1028   '06064'  TEN CHENNAI EXP    8.0         DG    DINDIGUL JN
# 1029   '06064'  TEN CHENNAI EXP    9.0         TPJ   TIRUCHCHIRAPALI
# 1030   '06064'  TEN CHENNAI EXP   10.0         VRI   VRIDHACHALAM JN
# 1031   '06064'  TEN CHENNAI EXP   11.0         VM    VILLUPURAM JN
# 1032   '06064'  TEN CHENNAI EXP   12.0         CGL   CHENGALPATTU
# 1033   '06064'  TEN CHENNAI EXP   13.0         TBM   TAMBARAM
# 1034   '06064'  TEN CHENNAI EXP   14.0         MBM   MAMBALAM
# ...

# %%
central = indianrailways[indianrailways.source_station_name.str.contains('CHENNAI CENTRAL')]

# %%
central.train_name.nunique()
# Out:
# 64

# %%
passenger = indianrailways[indianrailways.train_name.str.contains('PASSENGER')]

# %%
passenger.train_no.nunique()
# Out:
# 118

# %%
indianrailways[indianrailways.source_station_name.str.contains('AMRITSAR')]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 3888   '11058'  ASR CSTM  EXP      2.0         JNL   JANDIALA
# 3889   '11058'  ASR CSTM  EXP      3.0         BEAS  BEAS
# 3890   '11058'  ASR CSTM  EXP      4.0         KRE   KARTARPUR
# 3891   '11058'  ASR CSTM  EXP      5.0         JUC   JALANDHAR CITY
# 3892   '11058'  ASR CSTM  EXP      6.0         JRC   JALANDHAR CANT
# 3893   '11058'  ASR CSTM  EXP      7.0         PGW   PHAGWARA JN
# 3894   '11058'  ASR CSTM  EXP      8.0         GRY   GORAYA
# 3895   '11058'  ASR CSTM  EXP      9.0         PHR   PHILLAUR JN
# 3896   '11058'  ASR CSTM  EXP     10.0         LDH   LUDHIANA JN
# 3897   '11058'  ASR CSTM  EXP     11.0         AHH   AHMADGARH
# 3898   '11058'  ASR CSTM  EXP     12.0         MET   MALERKOTLA
# 3899   '11058'  ASR CSTM  EXP     13.0         DUI   DHURI JN
# 3900   '11058'  ASR CSTM  EXP     14.0         NBA   NABHA
# 3901   '11058'  ASR CSTM  EXP     15.0         PTA   PATIALA
# ...

# %%
indianrailways.dtypes
# Out:
# train_no                     object
# train_name                   object
# islno                       float64
# station_code                 object
# station_name                 object
# arrival_time                 object
# departing_time               object
# distance                    float64
# source_stationcode           object
# source_station_name          object
# destination_station_code     object
# destination_station_name     object
# dtype: object

# %%
bigP = indianrailways[indianrailways.train_no.str.contains('5938')]

# %%
bigP[bigP.train_no.str.contains('59386')]
# Out:
#       train_no       train_name  islno station_code     station_name  \
# 67918  '59386'  PANCHVALLEY  PA    1.0         AMLA  AMLA JN
# 67920  '59386'  PANCHVALLEY  PA    1.0         ET    ITARSI JN
# 67921  '59386'  PANCHVALLEY  PA    2.0         BHS   VIDISHA
# 67922  '59386'  PANCHVALLEY  PA    2.0         BHS   VIDISHA
# 67923  '59386'  PANCHVALLEY  PA    2.0         GNW   GANGIWARA
# 67924  '59386'  PANCHVALLEY  PA    3.0         BAQ   GANJ BASODA
# 67925  '59386'  PANCHVALLEY  PA    3.0         BAQ   GANJ BASODA
# 67926  '59386'  PANCHVALLEY  PA    3.0         KUX   KHIRSADOH JN
# 67927  '59386'  PANCHVALLEY  PA    4.0         BINA  BINA JN
# 67928  '59386'  PANCHVALLEY  PA    4.0         MABA  MANDI BAMORA
# 67929  '59386'  PANCHVALLEY  PA    4.0         PUX   PARASIA
# 67930  '59386'  PANCHVALLEY  PA    5.0         BINA  BINA JN
# 67931  '59386'  PANCHVALLEY  PA    5.0         IKR   IKLEHRA
# 67932  '59386'  PANCHVALLEY  PA    5.0         LAR   LALITPUR
# ...
