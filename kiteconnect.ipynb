# %%
import logging
from kiteconnect import KiteConnect

logging.basicConfig(level=logging.DEBUG)

kite = KiteConnect(api_key="7biditn53jjgs2h4")

# Redirect the user to the login url obtained
# from kite.login_url(), and receive the request_token
# from the registered redirect url after the login flow.
# Once you have the request_token, obtain the access_token
# as follows.

data = kite.generate_session("pycJzKM81xEg305BSHluUSN1YmaHhLll", api_secret="x1pzfk6j78xxos1f1t0wfhgp9skwjbzz")
kite.set_access_token(data["access_token"])
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /session/token HTTP/1.1" 200 None

# %%
data["access_token"]
# Out:
# 'HCXR1qTLIsMQuqwApDYGQTp3UEbpugHr'

# %%
kite.place_order()

# %%
kite.PRODUCT_CNC

# %%
# # Place an order
# try:
#     order_id = kite.place_order(tradingsymbol="RCOM",
#                                 exchange=kite.EXCHANGE_NSE,
#                                 transaction_type=kite.TRANSACTION_TYPE_BUY,
#                                 quantity=1,
#                                 order_type=kite.ORDER_TYPE_MARKET,
#                                 product=kite.PRODUCT_CNC,variety = 'regular')

#     logging.info("Order placed. ID is: {}".format(order_id))
# except Exception as e:
#     logging.info("Order placement failed: {}".format(e.message))

# # Fetch all orders
# kite.orders()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/1.1" 200 None
# INFO:root:Order placed. ID is: 181228001950380
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /orders HTTP/1.1" 200 None
# [{'placed_by': 'ST2101',
#   'order_id': '181228001941455',
#   'exchange_order_id': None,
#   'parent_order_id': None,
#   'status': 'REJECTED',
#   'status_message': 'RMS:Blocked for  EQUITY  nse_cm  NRML Remarks: Equity orders are not allowed in NRML product type  block type: ALL',
#   'order_timestamp': datetime.datetime(2018, 12, 28, 15, 2, 54),
#   'exchange_update_timestamp': None,
#   'exchange_timestamp': None,
#   'variety': 'regular',
#   'exchange': 'NSE',
#   'tradingsymbol': 'RCOM',
#   'instrument_token': 3375873,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
# ...

# %%
# Place an order
try:
    order_id = kite.place_order(tradingsymbol="RCOM",
                                exchange=kite.EXCHANGE_NSE,
                                transaction_type=kite.TRANSACTION_TYPE_BUY,
                                quantity=1,
                                order_type=kite.ORDER_TYPE_LIMIT,
                                product=kite.PRODUCT_CNC,variety = 'regular',price = 14.65)

    logging.info("Order placed. ID is: {}".format(order_id))
except Exception as e:
    logging.info("Order placement failed: {}".format(e.message))

# Fetch all orders
kite.orders()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/1.1" 200 None
# INFO:root:Order placed. ID is: 181228001979716
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /orders HTTP/1.1" 200 None
# [{'placed_by': 'ST2101',
#   'order_id': '181228001941455',
#   'exchange_order_id': None,
#   'parent_order_id': None,
#   'status': 'REJECTED',
#   'status_message': 'RMS:Blocked for  EQUITY  nse_cm  NRML Remarks: Equity orders are not allowed in NRML product type  block type: ALL',
#   'order_timestamp': datetime.datetime(2018, 12, 28, 15, 2, 54),
#   'exchange_update_timestamp': None,
#   'exchange_timestamp': None,
#   'variety': 'regular',
#   'exchange': 'NSE',
#   'tradingsymbol': 'RCOM',
#   'instrument_token': 3375873,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
# ...

# %%
# Place an order
try:
    order_id = kite.place_order(tradingsymbol="RCOM",
                                exchange=kite.EXCHANGE_NSE,
                                transaction_type=kite.TRANSACTION_TYPE_SELL,
                                quantity=1,
                                order_type=kite.ORDER_TYPE_MARKET,
                                product=kite.PRODUCT_CNC,variety = 'regular')

    logging.info("Order placed. ID is: {}".format(order_id))
except Exception as e:
    logging.info("Order placement failed: {}".format(e.message))

# Fetch all orders
kite.orders()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/1.1" 200 None
# INFO:root:Order placed. ID is: 181228002064046
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /orders HTTP/1.1" 200 None
# [{'placed_by': 'ST2101',
#   'order_id': '181228001941455',
#   'exchange_order_id': None,
#   'parent_order_id': None,
#   'status': 'REJECTED',
#   'status_message': 'RMS:Blocked for  EQUITY  nse_cm  NRML Remarks: Equity orders are not allowed in NRML product type  block type: ALL',
#   'order_timestamp': datetime.datetime(2018, 12, 28, 15, 2, 54),
#   'exchange_update_timestamp': None,
#   'exchange_timestamp': None,
#   'variety': 'regular',
#   'exchange': 'NSE',
#   'tradingsymbol': 'RCOM',
#   'instrument_token': 3375873,
#   'order_type': 'MARKET',
#   'transaction_type': 'BUY',
# ...
