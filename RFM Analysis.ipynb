# %%
import pandas as pd

# %%
rfm = pd.read_excel(R"C:\Users\Clustrex4\Downloads\rfm_sec.xlsx")

# %%
rfm
# Out:
#       CustomerID         InvoiceDate  recency  Frequency      Monetary  \
# 0          12347 2011-12-07 15:52:00        2          7  4.310000e+03
# 1          12348 2011-09-25 13:13:00       75          4  1.797240e+03
# 2          12349 2011-11-21 09:51:00       18          1  1.757550e+03
# 3          12350 2011-02-02 16:01:00      310          1  3.344000e+02
# 4          12352 2011-11-03 14:37:00       36         11  1.545410e+03
# 5          12353 2011-05-19 17:47:00      204          1  8.900000e+01
# 6          12354 2011-04-21 13:11:00      232          1  1.079400e+03
# 7          12355 2011-05-09 13:49:00      214          1  4.594000e+02
# 8          12356 2011-11-17 08:40:00       22          3  2.811430e+03
# 9          12357 2011-11-06 16:07:00       33          1  6.207670e+03
# 10         12358 2011-12-08 10:26:00        1          2  1.168060e+03
# 11         12359 2011-12-02 11:21:00        7          6  6.245530e+03
# ...

# %%
rfm.drop(['Segmentation'], axis=1)
# Out:
#       CustomerID         InvoiceDate  recency  Frequency      Monetary  \
# 0          12347 2011-12-07 15:52:00        2          7  4.310000e+03
# 1          12348 2011-09-25 13:13:00       75          4  1.797240e+03
# 2          12349 2011-11-21 09:51:00       18          1  1.757550e+03
# 3          12350 2011-02-02 16:01:00      310          1  3.344000e+02
# 4          12352 2011-11-03 14:37:00       36         11  1.545410e+03
# 5          12353 2011-05-19 17:47:00      204          1  8.900000e+01
# 6          12354 2011-04-21 13:11:00      232          1  1.079400e+03
# 7          12355 2011-05-09 13:49:00      214          1  4.594000e+02
# 8          12356 2011-11-17 08:40:00       22          3  2.811430e+03
# 9          12357 2011-11-06 16:07:00       33          1  6.207670e+03
# 10         12358 2011-12-08 10:26:00        1          2  1.168060e+03
# 11         12359 2011-12-02 11:21:00        7          6  6.245530e+03
# ...

# %%
newRFM = pd.DataFrame()

# %%
import numpy as np
def customersec(x):
    if ((x['R_Quartile'] in range(4,6)) & (x['FM_Quartile'] in np.arange(4,5.5,0.5) )):
        x['Segmentation'] = 'Champions'
        df2 = pd.DataFrame([[x['CustomerID'], x['InvoiceDate'], x['recency'], x['Frequency'], x['Monetary'], x['R_Quartile'], x['F_Quartile'], x['M_Quartile'], x['FM_Quartile'], x['RFM_Score'], x['Country'], x['Segmentation']]], columns=['CustomerID', 'InvoiceDate', 'recency', 'Frequency', 'Monetary', 'R_Quartile', 'F_Quartile', 'M_Quartile', 'FM_Quartile', 'RFM_Score', 'Country', 'Segmentation'])
        return df2
    else:
        return pd.DataFrame()
        #newRFM.append(df2)

# %%
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
newrfm123 = rfm.loc[:20,:].apply(customersec,axis =1)

# %%
rfm.head(20)
# Out:
#     CustomerID         InvoiceDate  recency  Frequency  Monetary  R_Quartile  \
# 0        12347 2011-12-07 15:52:00        2          7   4310.00           5
# 1        12348 2011-09-25 13:13:00       75          4   1797.24           2
# 2        12349 2011-11-21 09:51:00       18          1   1757.55           4
# 3        12350 2011-02-02 16:01:00      310          1    334.40           1
# 4        12352 2011-11-03 14:37:00       36         11   1545.41           3
# 5        12353 2011-05-19 17:47:00      204          1     89.00           1
# 6        12354 2011-04-21 13:11:00      232          1   1079.40           1
# 7        12355 2011-05-09 13:49:00      214          1    459.40           1
# 8        12356 2011-11-17 08:40:00       22          3   2811.43           4
# 9        12357 2011-11-06 16:07:00       33          1   6207.67           3
# 10       12358 2011-12-08 10:26:00        1          2   1168.06           5
# ...

# %%
newrfm123.dropna
# Out:
# 0        CustomerID         InvoiceDate  recency  Fr...
# 1                 Empty DataFrame
# Columns: []
# Index: []
# 2                 Empty DataFrame
# Columns: []
# Index: []
# 3                 Empty DataFrame
# Columns: []
# Index: []
# 4                 Empty DataFrame
# Columns: []
# Index: []
# 5                 Empty DataFrame
# Columns: []
# Index: []
# 6                 Empty DataFrame
# Columns: []
# Index: []
# 7                 Empty DataFrame
# Columns: []
# Index: []
# 8        CustomerID         InvoiceDate  recency  Fr...
# 9                 Empty DataFrame
# Columns: []
# Index: []
# 10                Empty DataFrame
# Columns: []
# Index: []
# 11       CustomerID         InvoiceDate  recency  Fr...
# 12                Empty DataFrame
# Columns: []
# Index: []
# 13                Empty DataFrame
# Columns: []
# Index: []
# 14       CustomerID         InvoiceDate  recency  Fr...
# 15                Empty DataFrame
# Columns: []
# Index: []
# ...
