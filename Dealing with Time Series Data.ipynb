# %%
import pandas as pd

# %%
reliance = pd.read_csv("A:\Hari\RELIANCE.csv")
reliance.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-08-08         NaN         NaN         NaN         NaN         NaN
# 1  2017-08-09  800.750000  810.000000  792.500000  799.400024  794.500488
# 2  2017-08-10  796.525024  803.325012  788.974976  792.174988  787.319702
# 3  2017-08-11  775.474976  790.000000  766.500000  773.125000  768.386475
# 4  2017-08-14  780.500000  792.250000  780.500000  786.525024  781.704407
#
#       Volume
# 0        NaN
# 1  4771286.0
# 2  4657686.0
# 3  7770128.0
# 4  6144598.0

# %%
reliance.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
reliance = pd.read_csv("A:\Hari\RELIANCE.csv",parse_dates=['Date'])
reliance.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object

# %%
reliance.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2017-08-08         NaN         NaN         NaN         NaN         NaN
# 1 2017-08-09  800.750000  810.000000  792.500000  799.400024  794.500488
# 2 2017-08-10  796.525024  803.325012  788.974976  792.174988  787.319702
# 3 2017-08-11  775.474976  790.000000  766.500000  773.125000  768.386475
# 4 2017-08-14  780.500000  792.250000  780.500000  786.525024  781.704407
#
#       Volume
# 0        NaN
# 1  4771286.0
# 2  4657686.0
# 3  7770128.0
# 4  6144598.0

# %%
ratings = pd.read_csv(R"A:\Hari\ml-latest-small\ml-latest-small\ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
ratings = pd.read_csv(R"A:\Hari\ml-latest-small\ml-latest-small\ratings.csv",parse_dates=['timestamp'])
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp     object
# dtype: object

# %%
ratings.timestamp = pd.to_datetime(ratings['timestamp'],unit='s')
ratings.dtypes
# Out:
# userId                int64
# movieId               int64
# rating              float64
# timestamp    datetime64[ns]
# dtype: object

# %%
ratings.head()
# Out:
#    userId  movieId  rating           timestamp
# 0       1       31     2.5 2009-12-14 02:52:24
# 1       1     1029     3.0 2009-12-14 02:52:59
# 2       1     1061     3.0 2009-12-14 02:53:02
# 3       1     1129     2.0 2009-12-14 02:53:05
# 4       1     1172     4.0 2009-12-14 02:53:25

# %%
ratings = pd.read_csv(R"A:\Hari\ml-latest-small\ml-latest-small\ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
import time
def dateparser (time1):
    return time.ctime(float(time1))

ratings = pd.read_csv(R"A:\Hari\ml-latest-small\ml-latest-small\ratings.csv",parse_dates=[3],date_parser=dateparser)
ratings.dtypes
# Out:
# userId                int64
# movieId               int64
# rating              float64
# timestamp    datetime64[ns]
# dtype: object

# %%
ratings.head()
# Out:
#    userId  movieId  rating           timestamp
# 0       1       31     2.5 2009-12-14 08:22:24
# 1       1     1029     3.0 2009-12-14 08:22:59
# 2       1     1061     3.0 2009-12-14 08:23:02
# 3       1     1129     2.0 2009-12-14 08:23:05
# 4       1     1172     4.0 2009-12-14 08:23:25

# %%
reliance.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2017-08-08         NaN         NaN         NaN         NaN         NaN
# 1 2017-08-09  800.750000  810.000000  792.500000  799.400024  794.500488
# 2 2017-08-10  796.525024  803.325012  788.974976  792.174988  787.319702
# 3 2017-08-11  775.474976  790.000000  766.500000  773.125000  768.386475
# 4 2017-08-14  780.500000  792.250000  780.500000  786.525024  781.704407
#
#       Volume
# 0        NaN
# 1  4771286.0
# 2  4657686.0
# 3  7770128.0
# 4  6144598.0

# %%
reliance.set_index('Date',inplace=True)
reliance.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-08-08         NaN         NaN         NaN         NaN         NaN
# 2017-08-09  800.750000  810.000000  792.500000  799.400024  794.500488
# 2017-08-10  796.525024  803.325012  788.974976  792.174988  787.319702
# 2017-08-11  775.474976  790.000000  766.500000  773.125000  768.386475
# 2017-08-14  780.500000  792.250000  780.500000  786.525024  781.704407
#
#                Volume
# Date
# 2017-08-08        NaN
# 2017-08-09  4771286.0
# 2017-08-10  4657686.0
# 2017-08-11  7770128.0
# 2017-08-14  6144598.0

# %%
type(reliance.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
reliance.index.max()
# Out:
# Timestamp('2018-08-08 00:00:00')

# %%
reliance.index.min()
# Out:
# Timestamp('2017-08-08 00:00:00')

# %%
reliance.shape
# Out:
# (251, 6)

# %%
reliance['2017']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-08-08         NaN         NaN         NaN         NaN         NaN
# 2017-08-09  800.750000  810.000000  792.500000  799.400024  794.500488
# 2017-08-10  796.525024  803.325012  788.974976  792.174988  787.319702
# 2017-08-11  775.474976  790.000000  766.500000  773.125000  768.386475
# 2017-08-14  780.500000  792.250000  780.500000  786.525024  781.704407
# 2017-08-16  786.000000  788.000000  775.099976  783.049988  778.250671
# 2017-08-17  784.500000  798.825012  780.575012  783.549988  778.747620
# 2017-08-18  782.000000  788.900024  776.575012  787.700012  782.872192
# 2017-08-21  788.500000  792.075012  780.125000  782.200012  777.405884
# 2017-08-22  786.000000  789.950012  778.025024  780.025024  775.244202
# 2017-08-23  782.424988  793.275024  776.575012  791.025024  786.176819
# 2017-08-24  795.000000  796.549988  782.250000  784.025024  779.219727
# ...

# %%
reliance['2017'].shape
# Out:
# (99, 6)

# %%
reliance["2018"]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-01   922.700012   922.700012   907.500000   909.750000   904.174133
# 2018-01-02   913.000000   919.549988   906.400024   911.150024   905.565552
# 2018-01-03   925.000000   926.000000   913.049988   914.799988   909.193176
# 2018-01-04   918.150024   921.799988   915.700012   920.299988   914.659424
# 2018-01-05   921.799988   926.900024   920.250000   923.250000   917.591370
# 2018-01-08   926.099976   931.000000   923.500000   928.549988   922.858887
# 2018-01-09   928.150024   943.900024   924.000000   940.950012   935.182922
# 2018-01-10   943.000000   947.400024   935.500000   942.349976   936.574280
# 2018-01-11   941.799988   942.650024   935.000000   937.750000   932.002502
# 2018-01-12   943.000000   952.799988   938.250000   949.000000   943.183533
# 2018-01-15   950.000000   958.500000   945.200012   949.150024   943.332642
# ...

# %%
reliance['2018'].shape
# Out:
# (152, 6)

# %%
reliance['2018-1']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-01  922.700012  922.700012  907.500000  909.750000  904.174133
# 2018-01-02  913.000000  919.549988  906.400024  911.150024  905.565552
# 2018-01-03  925.000000  926.000000  913.049988  914.799988  909.193176
# 2018-01-04  918.150024  921.799988  915.700012  920.299988  914.659424
# 2018-01-05  921.799988  926.900024  920.250000  923.250000  917.591370
# 2018-01-08  926.099976  931.000000  923.500000  928.549988  922.858887
# 2018-01-09  928.150024  943.900024  924.000000  940.950012  935.182922
# 2018-01-10  943.000000  947.400024  935.500000  942.349976  936.574280
# 2018-01-11  941.799988  942.650024  935.000000  937.750000  932.002502
# 2018-01-12  943.000000  952.799988  938.250000  949.000000  943.183533
# 2018-01-15  950.000000  958.500000  945.200012  949.150024  943.332642
# 2018-01-16  947.700012  947.700012  920.000000  922.950012  917.293213
# ...

# %%
reliance['2018-1']['Close'].mean()
# Out:
# 940.3931829090907

# %%
reliance['2018-1']['Close'].max()
# Out:
# 983.25

# %%
reliance['2018']['Close'].max()
# Out:
# 1217.699951

# %%
reliance['2017']['Close'].max()
# Out:
# 952.5499880000001

# %%
reliance['2017']['Close'].min()
# Out:
# 766.075012

# %%
reliance['2018']['Close'].min()
# Out:
# 882.7000119999999

# %%
reliance['2018-7-7':'2018-8-8']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-07-09   987.099976  1000.000000   983.500000   997.099976   997.099976
# 2018-07-10  1002.750000  1028.500000  1000.000000  1025.699951  1025.699951
# 2018-07-11  1025.000000  1040.900024  1017.849976  1038.800049  1038.800049
# 2018-07-12  1044.349976  1099.000000  1042.599976  1082.349976  1082.349976
# 2018-07-13  1080.500000  1109.000000  1080.000000  1099.800049  1099.800049
# 2018-07-16          NaN          NaN          NaN          NaN          NaN
# 2018-07-17  1078.300049  1095.949951  1069.599976  1092.349976  1092.349976
# 2018-07-18  1098.400024  1104.599976  1077.300049  1092.550049  1092.550049
# 2018-07-19  1093.300049  1115.000000  1086.349976  1104.849976  1104.849976
# 2018-07-20  1113.400024  1138.500000  1111.900024  1128.650024  1128.650024
# 2018-07-23  1129.800049  1129.800049  1113.099976  1120.300049  1120.300049
# ...

# %%
reliance.Close.resample('M').mean()
# Out:
# Date
# 2017-08-31     784.763342
# 2017-09-30     821.915475
# 2017-10-31     884.582501
# 2017-11-30     920.986356
# 2017-12-31     919.475003
# 2018-01-31     940.393183
# 2018-02-28     922.376311
# 2018-03-31     908.871049
# 2018-04-30     935.192854
# 2018-05-31     948.029541
# 2018-06-30     984.549999
# 2018-07-31    1069.071429
# 2018-08-31    1188.691630
# Freq: M, Name: Close, dtype: float64

# %%
reliance.Close.resample('y').mean()
# Out:
# Date
# 2017-12-31    871.168623
# 2018-12-31    968.451983
# Freq: A-DEC, Name: Close, dtype: float64

# %%
reliance.Close.resample('Q').mean()
# Out:
# Date
# 2017-09-30     806.435420
# 2017-12-31     908.755644
# 2018-03-31     924.705831
# 2018-06-30     955.800778
# 2018-09-30    1095.653696
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
ratings[(ratings['timestamp'] > '1990') & (ratings['rating']>4.5)]
# Out:
#        userId  movieId  rating           timestamp
# 21          2       17     5.0 1996-06-21 11:14:41
# 22          2       39     5.0 1996-06-21 11:13:24
# 29          2      150     5.0 1996-06-21 11:09:55
# 37          2      222     5.0 1996-06-21 11:17:20
# 44          2      265     5.0 1996-06-21 11:14:57
# 45          2      266     5.0 1996-06-21 11:13:06
# 83          2      551     5.0 1996-06-21 11:16:07
# 85          2      585     5.0 1996-06-21 11:16:57
# 89          2      589     5.0 1996-06-21 11:14:57
# 90          2      590     5.0 1996-06-21 11:09:55
# 91          2      592     5.0 1996-06-21 11:09:55
# 101         3      318     5.0 2011-02-28 03:02:01
# 103         3      356     5.0 2011-02-28 03:02:47
# 113         3     1197     5.0 2011-02-28 22:39:30
# 130         3     2959     5.0 2011-02-28 03:14:34
# 133         3     3949     5.0 2011-02-28 03:19:34
# 148         4       34     5.0 2000-02-07 10:32:36
# ...

# %%
ratings['year'] = ratings.timestamp.dt.year
ratings.head()
# Out:
#    userId  movieId  rating           timestamp  year
# 0       1       31     2.5 2009-12-14 02:52:24  2009
# 1       1     1029     3.0 2009-12-14 02:52:59  2009
# 2       1     1061     3.0 2009-12-14 02:53:02  2009
# 3       1     1129     2.0 2009-12-14 02:53:05  2009
# 4       1     1172     4.0 2009-12-14 02:53:25  2009

# %%
pd.date_range(start = '8/9/2018',end='8/9/2019')
# Out:
# DatetimeIndex(['2018-08-09', '2018-08-10', '2018-08-11', '2018-08-12',
#                '2018-08-13', '2018-08-14', '2018-08-15', '2018-08-16',
#                '2018-08-17', '2018-08-18',
#                ...
#                '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-03',
#                '2019-08-04', '2019-08-05', '2019-08-06', '2019-08-07',
#                '2019-08-08', '2019-08-09'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
len(pd.date_range(start = '8/9/2018',end='8/9/2019',freq='B'))
# Out:
# 262

# %%
pd.date_range(start = '3/30/2018',end='5/31/2018',freq='M')
# Out:
# DatetimeIndex(['2018-03-31', '2018-04-30', '2018-05-31'], dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start = '8/9/2018',end='8/9/2019',freq='3M')
# Out:
# DatetimeIndex(['2018-08-31', '2018-11-30', '2019-02-28', '2019-05-31'], dtype='datetime64[ns]', freq='3M')

# %%
pd.date_range(start = '8/9/2018',end='8/9/2019',freq='20D')
# Out:
# DatetimeIndex(['2018-08-09', '2018-08-29', '2018-09-18', '2018-10-08',
#                '2018-10-28', '2018-11-17', '2018-12-07', '2018-12-27',
#                '2019-01-16', '2019-02-05', '2019-02-25', '2019-03-17',
#                '2019-04-06', '2019-04-26', '2019-05-16', '2019-06-05',
#                '2019-06-25', '2019-07-15', '2019-08-04'],
#               dtype='datetime64[ns]', freq='20D')

# %%
len(pd.date_range(start = '8/9/2018',end='8/9/2019',freq='20D'))
# Out:
# 19

# %%
pd.DataFrame(pd.date_range(start = '8/9/2018',end='8/9/2019',freq='20D'),columns= ['Date'])
# Out:
#          Date
# 0  2018-08-09
# 1  2018-08-29
# 2  2018-09-18
# 3  2018-10-08
# 4  2018-10-28
# 5  2018-11-17
# 6  2018-12-07
# 7  2018-12-27
# 8  2019-01-16
# 9  2019-02-05
# 10 2019-02-25
# 11 2019-03-17
# 12 2019-04-06
# 13 2019-04-26
# 14 2019-05-16
# 15 2019-06-05
# 16 2019-06-25
# 17 2019-07-15
# 18 2019-08-04
