# %%
from apyori import apriori

# %%
import pandas as pd

# %%
orders = pd.read_csv("A:\Frequently bought togher\instacart_2017_05_01\orders.csv")
orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# 5         3367565        1    prior             6          2
# 6          550135        1    prior             7          1
# 7         3108588        1    prior             8          1
# 8         2295261        1    prior             9          1
# 9         2550362        1    prior            10          4
# 10        1187899        1    train            11          4
# 11        2168274        2    prior             1          2
# 12        1501582        2    prior             2          5
# 13        1901567        2    prior             3          1
# 14         738281        2    prior             4          2
# 15        1673511        2    prior             5          3
# 16        1199898        2    prior             6          2
# 17        3194192        2    prior             7          2
# 18         788338        2    prior             8          1
# 19        1718559        2    prior             9          2
# 20        1447487        2    prior            10          1
# 21        1402090        2    prior            11          1
# 22        3186735        2    prior            12          1
# 23        3268552        2    prior            13          4
# 24         839880        2    prior            14          3
# 25        1492625        2    train            15          1
# 26        1374495        3    prior             1          1
# 27         444309        3    prior             2          3
# 28        3002854        3    prior             3          3
# 29        2037211        3    prior             4          2
# ...           ...      ...      ...           ...        ...
# 3421053   2789700   206208    prior            35          3
# 3421054    844592   206208    prior            36          6
# 3421055   1541132   206208    prior            37          2
# 3421056   2808240   206208    prior            38          0
# 3421057   3027766   206208    prior            39          2
# 3421058   3356245   206208    prior            40          5
# 3421059    442304   206208    prior            41          2
# 3421060   2675140   206208    prior            42          1
# 3421061    167903   206208    prior            43          4
# 3421062   2393201   206208    prior            44          6
# 3421063   3292671   206208    prior            45          2
# 3421064   3059777   206208    prior            46          1
# 3421065   2239861   206208    prior            47          3
# 3421066   1285346   206208    prior            48          1
# 3421067   1882108   206208    prior            49          1
# 3421068    803273   206208     test            50          5
# 3421069   3154581   206209    prior             1          3
# 3421070   1889163   206209    prior             2          3
# 3421071   1542354   206209    prior             3          5
# 3421072    688306   206209    prior             4          1
# 3421073   2307371   206209    prior             5          4
# 3421074   3186442   206209    prior             6          0
# 3421075    550836   206209    prior             7          2
# 3421076   2129269   206209    prior             8          3
# 3421077   2558525   206209    prior             9          4
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# 5                        7                    19.0
# 6                        9                    20.0
# 7                       14                    14.0
# 8                       16                     0.0
# 9                        8                    30.0
# 10                       8                    14.0
# 11                      11                     NaN
# 12                      10                    10.0
# 13                      10                     3.0
# 14                      10                     8.0
# 15                      11                     8.0
# 16                       9                    13.0
# 17                      12                    14.0
# 18                      15                    27.0
# 19                       9                     8.0
# 20                      11                     6.0
# 21                      10                    30.0
# 22                       9                    28.0
# 23                      11                    30.0
# 24                      10                    13.0
# 25                      11                    30.0
# 26                      14                     NaN
# 27                      19                     9.0
# 28                      16                    21.0
# 29                      18                    20.0
# ...                    ...                     ...
# 3421053                 22                     4.0
# 3421054                 15                    10.0
# 3421055                 12                     3.0
# 3421056                 15                    19.0
# 3421057                 14                     9.0
# 3421058                  9                    10.0
# 3421059                 14                    11.0
# 3421060                 19                     6.0
# 3421061                 14                     3.0
# 3421062                 16                     2.0
# 3421063                 11                     3.0
# 3421064                 10                    13.0
# 3421065                  4                     9.0
# 3421066                 11                     5.0
# 3421067                 22                     7.0
# 3421068                 11                     4.0
# 3421069                 11                     NaN
# 3421070                 17                     7.0
# 3421071                 11                    30.0
# 3421072                 10                    30.0
# 3421073                 15                     3.0
# 3421074                 16                     3.0
# 3421075                 13                     9.0
# 3421076                 17                    22.0
# 3421077                 15                    22.0
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0
#
# [3421083 rows x 7 columns]

# %%
orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
products = pd.read_csv("A:\Frequently bought togher\instacart_2017_05_01\products.csv")
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# 5               6                                       Dry Nose Oil
# 6               7                     Pure Coconut Water With Orange
# 7               8                  Cut Russet Potatoes Steam N' Mash
# 8               9                  Light Strawberry Blueberry Yogurt
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# 10             11                                  Peach Mango Juice
# 11             12                         Chocolate Fudge Layer Cake
# 12             13                                  Saline Nasal Mist
# 13             14                     Fresh Scent Dishwasher Cleaner
# 14             15                           Overnight Diapers Size 6
# 15             16                      Mint Chocolate Flavored Syrup
# 16             17                                  Rendered Duck Fat
# 17             18                Pizza for One Suprema  Frozen Pizza
# 18             19   Gluten Free Quinoa Three Cheese & Mushroom Blend
# 19             20     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 20             21                   Small & Medium Dental Dog Treats
# 21             22                  Fresh Breath Oral Rinse Mild Mint
# 22             23                             Organic Turkey Burgers
# 23             24  Tri-Vi-Sol® Vitamins A-C-and D Supplement Drop...
# 24             25            Salted Caramel Lean Protein & Fiber Bar
# 25             26        Fancy Feast Trout Feast Flaked Wet Cat Food
# 26             27  Complete Spring Water Foaming Antibacterial Ha...
# 27             28                                  Wheat Chex Cereal
# 28             29  Fresh Cut Golden Sweet No Salt Added Whole Ker...
# 29             30         Three Cheese Ziti, Marinara with Meatballs
# ...           ...                                                ...
# 49658       49659                            Organic Creamed Coconut
# 49659       49660                        Professionals Sleek Shampoo
# 49660       49661                                              Porto
# 49661       49662                       Bacon Cheddar Pretzel Pieces
# 49662       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49663       49664                     Lemon Cayenne Drinking Vinegar
# 49664       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49665       49666                      Ginger Snaps Snacking Cookies
# 49666       49667           Enchilada with Spanish Rice & Beans Meal
# 49667       49668                     Apple Cinnamon Scented Candles
# 49668       49669                                   K Cup Dark Blend
# 49669       49670                                Beef Summer Sausage
# 49670       49671                               Milk Chocolate Drops
# 49671       49672                             Cafe Mocha K-Cup Packs
# 49672       49673              Stone Baked Multi Grain Artisan Rolls
# 49673       49674            Frozen Greek Yogurt Bars Chocolate Chip
# 49674       49675                Cinnamon Dolce Keurig Brewed K Cups
# 49675       49676                             Ultra Red Energy Drink
# 49676       49677                    Thick & Chunky Sloppy Joe Sauce
# 49677       49678                    Large Chicken & Cheese Taquitos
# 49678       49679                            Famous Chocolate Wafers
# 49679       49680                 All Natural Creamy Caesar Dressing
# 49680       49681            Spaghetti with Meatballs and Sauce Meal
# 49681       49682                                 California Limeade
# 49682       49683                                     Cucumber Kirby
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# 5            11             11
# 6            98              7
# 7           116              1
# 8           120             16
# 9           115              7
# 10           31              7
# 11          119              1
# 12           11             11
# 13           74             17
# 14           56             18
# 15          103             19
# 16           35             12
# 17           79              1
# 18           63              9
# 19           98              7
# 20           40              8
# 21           20             11
# 22           49             12
# 23           47             11
# 24            3             19
# 25           41              8
# 26          127             11
# 27          121             14
# 28           81             15
# 29           38              1
# ...         ...            ...
# 49658        17             13
# 49659        22             11
# 49660       134              5
# 49661       107             19
# 49662        57             14
# 49663       100             21
# 49664        45             19
# 49665        61             19
# 49666        38              1
# 49667       101             17
# 49668       100             21
# 49669       106             12
# 49670        45             19
# 49671        26              7
# 49672       129              1
# 49673        37              1
# 49674        26              7
# 49675        64              7
# 49676        59             15
# 49677       129              1
# 49678        61             19
# 49679        89             13
# 49680        38              1
# 49681        98              7
# 49682        83              4
# 49683       124              5
# 49684        42              1
# 49685       112              3
# 49686        41              8
# 49687        73             11
#
# [49688 rows x 4 columns]

# %%
products.product_id.nunique()
# Out:
# 49688

# %%
products.product_name.nunique()
# Out:
# 49688

# %%
orders_products_prior = pd.read_csv("A:\Frequently bought togher\instacart_2017_05_01\order_products__prior.csv")
orders_products_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# 5                2       17794                  6          1
# 6                2       40141                  7          1
# 7                2        1819                  8          1
# 8                2       43668                  9          0
# 9                3       33754                  1          1
# 10               3       24838                  2          1
# 11               3       17704                  3          1
# 12               3       21903                  4          1
# 13               3       17668                  5          1
# 14               3       46667                  6          1
# 15               3       17461                  7          1
# 16               3       32665                  8          1
# 17               4       46842                  1          0
# 18               4       26434                  2          1
# 19               4       39758                  3          1
# 20               4       27761                  4          1
# 21               4       10054                  5          1
# 22               4       21351                  6          1
# 23               4       22598                  7          1
# 24               4       34862                  8          1
# 25               4       40285                  9          1
# 26               4       17616                 10          1
# 27               4       25146                 11          1
# 28               4       32645                 12          1
# 29               4       41276                 13          1
# ...            ...         ...                ...        ...
# 32434459   3421080       41950                  4          0
# 32434460   3421080       31717                  5          0
# 32434461   3421080       12935                  6          1
# 32434462   3421080       25122                  7          0
# 32434463   3421080       10667                  8          0
# 32434464   3421080       38061                  9          0
# 32434465   3421081       38185                  1          0
# 32434466   3421081       12218                  2          0
# 32434467   3421081       32299                  3          0
# 32434468   3421081        3060                  4          0
# 32434469   3421081       20539                  5          0
# 32434470   3421081       35221                  6          0
# 32434471   3421081       12861                  7          0
# 32434472   3421082       17279                  1          1
# 32434473   3421082       12738                  2          1
# 32434474   3421082       16797                  3          0
# 32434475   3421082       43352                  4          1
# 32434476   3421082       32700                  5          1
# 32434477   3421082       12023                  6          0
# 32434478   3421082       47941                  7          0
# 32434479   3421083        7854                  1          0
# 32434480   3421083       45309                  2          0
# 32434481   3421083       21162                  3          0
# 32434482   3421083       18176                  4          1
# 32434483   3421083       35211                  5          0
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
orders_products_prior.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
orders_products_train = pd.read_csv("A:\Frequently bought togher\instacart_2017_05_01\order_products__train.csv")
orders_products_train
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0               1       49302                  1          1
# 1               1       11109                  2          1
# 2               1       10246                  3          0
# 3               1       49683                  4          0
# 4               1       43633                  5          1
# 5               1       13176                  6          0
# 6               1       47209                  7          0
# 7               1       22035                  8          1
# 8              36       39612                  1          0
# 9              36       19660                  2          1
# 10             36       49235                  3          0
# 11             36       43086                  4          1
# 12             36       46620                  5          1
# 13             36       34497                  6          1
# 14             36       48679                  7          1
# 15             36       46979                  8          1
# 16             38       11913                  1          0
# 17             38       18159                  2          0
# 18             38        4461                  3          0
# 19             38       21616                  4          1
# 20             38       23622                  5          0
# 21             38       32433                  6          0
# 22             38       28842                  7          0
# 23             38       42625                  8          0
# 24             38       39693                  9          0
# 25             96       20574                  1          1
# 26             96       30391                  2          0
# 27             96       40706                  3          1
# 28             96       25610                  4          0
# 29             96       27966                  5          1
# ...           ...         ...                ...        ...
# 1384587   3421026       32237                  3          0
# 1384588   3421026          10                  4          0
# 1384589   3421026        4493                  5          0
# 1384590   3421026        7781                  6          0
# 1384591   3421049       40800                  1          0
# 1384592   3421049       17706                  2          0
# 1384593   3421049       33424                  3          1
# 1384594   3421049       17299                  4          0
# 1384595   3421049       26800                  5          0
# 1384596   3421049       34243                  6          0
# 1384597   3421056        5750                  1          1
# 1384598   3421056        9340                  2          1
# 1384599   3421056       21709                  3          1
# 1384600   3421056       16475                  4          0
# 1384601   3421056       12432                  5          0
# 1384602   3421058       15629                  1          1
# 1384603   3421058        4347                  2          1
# 1384604   3421058       34466                  3          1
# 1384605   3421058        6244                  4          1
# 1384606   3421058        6858                  5          1
# 1384607   3421058       30316                  6          1
# 1384608   3421058       35578                  7          0
# 1384609   3421058       32650                  8          1
# 1384610   3421063       49235                  1          1
# 1384611   3421063       13565                  2          1
# 1384612   3421063       14233                  3          1
# 1384613   3421063       35548                  4          1
# 1384614   3421070       35951                  1          1
# 1384615   3421070       16953                  2          1
# 1384616   3421070        4724                  3          1
#
# [1384617 rows x 4 columns]

# %%
orders_products_train.shape
# Out:
# (1384617, 4)

# %%
orders_products_prior.shape
# Out:
# (32434489, 4)

# %%
sample_orders = orders_products_prior.head(1000000)
#sample_orders = orders_products_prior.copy()
sample_orders =  sample_orders.merge(orders,on='order_id')
sample_orders.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0

# %%
sample_orders = sample_orders.merge(products,on='product_id')
sample_orders.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1        26       33120                  5          0   153404    prior
# 2       120       33120                 13          0    23750    prior
# 3       327       33120                  5          1    58707    prior
# 4       390       33120                 28          1   166654    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             2          0                 16                     7.0
# 2            11          6                  8                    10.0
# 3            21          6                  9                     8.0
# 4            48          0                 12                     9.0
#
#          product_name  aisle_id  department_id
# 0  Organic Egg Whites        86             16
# 1  Organic Egg Whites        86             16
# 2  Organic Egg Whites        86             16
# 3  Organic Egg Whites        86             16
# 4  Organic Egg Whites        86             16

# %%
sample_orders.product_name.value_counts()
# Out:
# Banana                                                                           14759
# Bag of Organic Bananas                                                           11867
# Organic Strawberries                                                              8138
# Organic Baby Spinach                                                              7477
# Organic Hass Avocado                                                              6551
# Organic Avocado                                                                   5379
# Large Lemon                                                                       4700
# Strawberries                                                                      4388
# Limes                                                                             4317
# Organic Raspberries                                                               4238
# Organic Whole Milk                                                                4153
# Organic Yellow Onion                                                              3446
# Organic Garlic                                                                    3376
# Organic Zucchini                                                                  3244
# Organic Blueberries                                                               3121
# Cucumber Kirby                                                                    2981
# Organic Fuji Apple                                                                2739
# Organic Lemon                                                                     2735
# Apple Honeycrisp Organic                                                          2625
# Organic Grape Tomatoes                                                            2568
# Seedless Red Grapes                                                               2531
# Honeycrisp Apple                                                                  2505
# Organic Half & Half                                                               2477
# Organic Cucumber                                                                  2455
# Organic Baby Carrots                                                              2358
# Organic Gala Apples                                                               2341
# Sparkling Water Grapefruit                                                        2304
# Organic Large Extra Fancy Fuji Apple                                              2296
# Carrots                                                                           2268
# Organic Baby Arugula                                                              2224
#                                                                                  ...
# Dry Arbol Peppers                                                                    1
# California Peach Lowfat Yogurt                                                       1
# Bread Crumbs, Plain                                                                  1
# Orange Mango Naturally Flavored Sparkling Water                                      1
# Organic Pure Cane Sugar                                                              1
# Fiesta Blend Vegetables                                                              1
# Tri-Color Penne Pasta                                                                1
# Multigrain Sandwich Rounds                                                           1
# Gf Cheddar Organic Otg                                                               1
# Decorating Green Cake Icing                                                          1
# Allergy 24 Hour 10mg Posted 10/28/2013 Dissolve Tabs                                 1
# Smartblend True Instinct Turkey & Venison Dog Food                                   1
# Antioxidant Super Tea Pomegranate Honey Green Tea                                    1
# Jambalaya Original Rice Mix                                                          1
# Chef's Cut, Tomatoes with Basil Leaf                                                 1
# Overnight Pads with Wings                                                            1
# Wasabi Sauce                                                                         1
# Whiskey, Tennessee Honey, Original Recipe                                            1
# Soothing with Aloe Body Lotion                                                       1
# Petite Crab Cakes                                                                    1
# Meyer Ginger Lemonade                                                                1
# Coffee Cake                                                                          1
# French Onion Dip Potato Crisps                                                       1
# Thermal Creations Heat Tamer Leave-In Spray                                          1
# Air Effects Febreze Air Effects with Downy April Fresh Air Freshener Air Care        1
# Roasted Ground Coriander                                                             1
# Sweet & Creamy Regular Medium Roast Iced K-Cups Arabica Coffee                       1
# Fruit Smoothies SPF 15 Lip Protectant                                                1
# Black Bean, Organic, Spaghetti Shape                                                 1
# Crab Meat Backfin Lump                                                               1
# Name: product_name, Length: 35098, dtype: int64

# %%
sample_orders.shape
# Out:
# (1000000, 13)

# %%
sample_orders.order_id.nunique()
# Out:
# 99260

# %%
sample_orders.product_id.nunique()
# Out:
# 35098

# %%
sample_orders.dtypes
# Out:
# order_id                    int64
# product_id                  int64
# add_to_cart_order           int64
# reordered                   int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# product_name               object
# aisle_id                    int64
# department_id               int64
# dtype: object

# %%
sample_orders2 = sample_orders.groupby(['order_id','product_name'],as_index=False)['product_id'].count()
#sample_orders2 = sample_orders2.pivot_table(index = ['order_id'], columns='product_name',values='product_id',aggfunc= lambda x: x).reset_index()
#.fillna(0)
#.unstack().fillna(0)
sample_orders2 = sample_orders2.iloc[:,:-1]

# %%
sample_orders2.head(2)
# Out:
#    order_id                              product_name
# 0         2  All Natural No Stir Creamy Almond Butter
# 1         2                                   Carrots

# %%
pd.get_dummies(sample_orders2['product_name'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-fca45850402f> in <module>()
# ----> 1 pd.get_dummies(sample_orders2['product_name'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     885                                  sparse=sparse,
#     886                                  drop_first=drop_first,
# --> 887                                  dtype=dtype)
#     888     return result
#     889
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     966
#     967     else:
# --> 968         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#     969
#     970         if not dummy_na:
#
# MemoryError:

# %%
market_basket = sample_orders.groupby('order_id')['product_name'].apply(list)
market_basket = market_basket.reset_index()
market_basket
# Out:
#        order_id                                       product_name
# 0             2  [Organic Egg Whites, Michigan Organic Kale, Ga...
# 1             3  [Total 2% with Strawberry Lowfat Greek Straine...
# 2             4  [Plain Pre-Sliced Bagels, Honey/Lemon Cough Dr...
# 3             5  [Bag of Organic Bananas, Just Crisp, Parmesan,...
# 4             6  [Cleanse, Dryer Sheets Geranium Scent, Clean D...
# 5             7                   [Orange Juice, Pineapple Chunks]
# 6             8                    [Original Hawaiian Sweet Rolls]
# 7             9  [Organic Red Radish, Bunch, Whole White Mushro...
# 8            10  [Green Beans, Banana, Baby Portabella Mushroom...
# 9            11  [Extra Virgin Olive Oil, Teriyaki & Pineapple ...
# 10           12  [French Vanilla Coffee Creamer, 2% Milk, Cheru...
# 11           13  [Light, Chunky Salsa Medium, Handmade Vodka Fr...
# 12           14  [Hair Bender Whole Bean Coffee, Organic Whole ...
# 13           15  [Spring Water, Organic Extra Virgin Olive Oil,...
# 14           16  [Original Popcorn, Water, Sea Salt Made With O...
# 15           18  [Organic Raspberries, Organic Avocado, 100% Re...
# 16           19  [Unsweetened Almondmilk, Organic Baby Carrots,...
# 17           20  [Banana, Nilla Wafers, Mini Chocolate Chip Waf...
# 18           21  [Yuba Tofu Skin, Organic Firm Tofu, Frozen Org...
# 19           22  [2% Reduced Fat Milk, Banana, Asparagus, Butte...
# 20           23  [Organic Avocado, Organic Baby Spinach Salad, ...
# 21           24  [Strawberry Lemonade Frozen Pops, Mint Chocola...
# 22           25  [Original Popcorn, Boomchickapop Sweet & Salty...
# 23           26  [Organic Egg Whites, Organic Baby Spinach, Ban...
# 24           27  [Michigan Organic Kale, Carrots, Bag of Organi...
# 25           28  [Air Chilled Organic Boneless Skinless Chicken...
# 26           29  [Bag of Organic Bananas, Raspberries, Smartwat...
# 27           30  [Synergy Organic Kombucha Gingerberry, Mango C...
# 28           31  [Organic Baby Spinach, Organic Cilantro, Earl ...
# 29           32  [Bag of Organic Bananas, Organic Bread with 21...
# ...         ...                                                ...
# 99230    105598  [Organic Bosc Pear, Green Bell Pepper, Organic...
# 99231    105599  [Whole Bean French Roast Dark Roast Blend Extr...
# 99232    105600  [Carrots, Seedless Watermelon, European Cucumb...
# 99233    105601  [Organic Avocado, Roasted & Salted Almonds, Cu...
# 99234    105602  [Bag of Organic Bananas, Extra Virgin Olive Oi...
# 99235    105603  [Indian Mattar Paneer, Indian Paneer Tikka, Ch...
# 99236    105604  [Bag of Organic Bananas, Everyday  Facial Tiss...
# 99237    105605  [White Sugar Free Peppermint Gum, Non-Drowsy O...
# 99238    105607  [Organic Raspberries, Organic Avocado, Organic...
# 99239    105608  [Organic Raspberries, Organic Strawberries, Or...
# 99240    105609  [Bag of Organic Bananas, Organic Hass Avocado,...
# 99241    105610  [Beef Franks, Organic 2% Reduced Fat Milk, Min...
# 99242    105611  [Ultra Soft Facial Tissues, Shepherd's Pie, Pe...
# 99243    105612  [Sparkling Water Grapefruit, Deli Fresh Honey ...
# 99244    105613  [Bag of Organic Bananas, Organic Raspberries, ...
# 99245    105614  [Large Lemon, Limes, Chocolate Chip Cookies, C...
# 99246    105615  [Organic Strawberries, Cold Brew Coffee, Potat...
# 99247    105616  [Bag of Organic Bananas, Organic Cilantro, Org...
# 99248    105617  [Organic Strawberries, Honeycrisp Apple, Limes...
# 99249    105618  [Organic Baby Spinach, Organic Whole Milk, Bon...
# 99250    105619  [Sparkling Water Grapefruit, Blackberry Cucumb...
# 99251    105620  [Organic Ginger Root, White Corn, Red Peppers,...
# 99252    105622  [Bag of Organic Bananas, Organic Baby Carrots,...
# 99253    105623  [Boneless Skinless Chicken Breast Fillets, Cle...
# 99254    105624  [Cold Brew Coffee, Cage Free Large White Eggs,...
# 99255    105625  [Dinner Classic White 10.375\" Dinner Plate, O...
# 99256    105626  [Non Fat Greek Yogurt, Liquid Egg Whites, Orga...
# 99257    105627  [Organic Shredded Mozzarella, Organic Chopped ...
# 99258    105628  [Bag of Organic Bananas, Organic Gala Apples, ...
# 99259    105629  [Organic Baby Spinach, Organic Raspberries, Ba...
#
# [99260 rows x 2 columns]

# %%
market_basket['product_name']
# Out:
# 0        ['Organic Egg Whites', 'Michigan Organic Kale'...
# 1        ['Total 2% with Strawberry Lowfat Greek Strain...
# 2        ['Plain Pre-Sliced Bagels', 'Honey/Lemon Cough...
# 3        ['Bag of Organic Bananas', 'Just Crisp, Parmes...
# 4        ['Cleanse', 'Dryer Sheets Geranium Scent', 'Cl...
# 5                     ['Orange Juice', 'Pineapple Chunks']
# 6                        ['Original Hawaiian Sweet Rolls']
# 7        ['Organic Red Radish, Bunch', 'Whole White Mus...
# 8        ['Green Beans', 'Banana', 'Baby Portabella Mus...
# 9        ['Extra Virgin Olive Oil', 'Teriyaki & Pineapp...
# 10       ['French Vanilla Coffee Creamer', '2% Milk', '...
# 11       ['Light', 'Chunky Salsa Medium', 'Handmade Vod...
# 12       ['Hair Bender Whole Bean Coffee', 'Organic Who...
# 13       ['Spring Water', 'Organic Extra Virgin Olive O...
# 14       ['Original Popcorn', 'Water', 'Sea Salt Made W...
# 15       ['Organic Raspberries', 'Organic Avocado', '10...
# 16       ['Unsweetened Almondmilk', 'Organic Baby Carro...
# 17       ['Banana', 'Nilla Wafers', 'Mini Chocolate Chi...
# 18       ['Yuba Tofu Skin', 'Organic Firm Tofu', 'Froze...
# 19       ['2% Reduced Fat Milk', 'Banana', 'Asparagus',...
# 20       ['Organic Avocado', 'Organic Baby Spinach Sala...
# 21       ['Strawberry Lemonade Frozen Pops', 'Mint Choc...
# 22       ['Original Popcorn', 'Boomchickapop Sweet & Sa...
# 23       ['Organic Egg Whites', 'Organic Baby Spinach',...
# 24       ['Michigan Organic Kale', 'Carrots', 'Bag of O...
# 25       ['Air Chilled Organic Boneless Skinless Chicke...
# 26       ['Bag of Organic Bananas', 'Raspberries', 'Sma...
# 27       ['Synergy Organic Kombucha Gingerberry', 'Mang...
# 28       ['Organic Baby Spinach', 'Organic Cilantro', '...
# 29       ['Bag of Organic Bananas', 'Organic Bread with...
#                                ...
# 99230    ['Organic Bosc Pear', 'Green Bell Pepper', "Or...
# 99231    ['Whole Bean French Roast Dark Roast Blend Ext...
# 99232    ['Carrots', 'Seedless Watermelon', 'European C...
# 99233    ['Organic Avocado', 'Roasted & Salted Almonds'...
# 99234    ['Bag of Organic Bananas', 'Extra Virgin Olive...
# 99235    ['Indian Mattar Paneer', 'Indian Paneer Tikka'...
# 99236    ['Bag of Organic Bananas', 'Everyday  Facial T...
# 99237    ['White Sugar Free Peppermint Gum', 'Non-Drows...
# 99238    ['Organic Raspberries', 'Organic Avocado', 'Or...
# 99239    ['Organic Raspberries', 'Organic Strawberries'...
# 99240    ['Bag of Organic Bananas', 'Organic Hass Avoca...
# 99241    ['Beef Franks', 'Organic 2% Reduced Fat Milk',...
# 99242    ['Ultra Soft Facial Tissues', "Shepherd's Pie"...
# 99243    ['Sparkling Water Grapefruit', 'Deli Fresh Hon...
# 99244    ['Bag of Organic Bananas', 'Organic Raspberrie...
# 99245    ['Large Lemon', 'Limes', 'Chocolate Chip Cooki...
# 99246    ['Organic Strawberries', 'Cold Brew Coffee', '...
# 99247    ['Bag of Organic Bananas', 'Organic Cilantro',...
# 99248    ['Organic Strawberries', 'Honeycrisp Apple', '...
# 99249    ['Organic Baby Spinach', 'Organic Whole Milk',...
# 99250    ['Sparkling Water Grapefruit', 'Blackberry Cuc...
# 99251    ['Organic Ginger Root', 'White Corn', 'Red Pep...
# 99252    ['Bag of Organic Bananas', 'Organic Baby Carro...
# 99253    ['Boneless Skinless Chicken Breast Fillets', '...
# 99254    ['Cold Brew Coffee', 'Cage Free Large White Eg...
# 99255    ['Dinner Classic White 10.375\\" Dinner Plate'...
# 99256    ['Non Fat Greek Yogurt', 'Liquid Egg Whites', ...
# 99257    ['Organic Shredded Mozzarella', 'Organic Chopp...
# 99258    ['Bag of Organic Bananas', 'Organic Gala Apple...
# 99259    ['Organic Baby Spinach', 'Organic Raspberries'...
# Name: product_name, Length: 99260, dtype: object

# %%
sample_orders[sample_orders.order_id == 10557]
# Out:
#         order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 107014     10557       19660                  3          1   186847    prior
# 339152     10557       30489                  4          1   186847    prior
# 741065     10557         343                  5          0   186847    prior
# 823795     10557       42803                  1          1   186847    prior
# 938513     10557       23198                  2          1   186847    prior
#
#         order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 107014            43          5                 12                     4.0
# 339152            43          5                 12                     4.0
# 741065            43          5                 12                     4.0
# 823795            43          5                 12                     4.0
# 938513            43          5                 12                     4.0
#
#                              product_name  aisle_id  department_id
# 107014                       Spring Water       115              7
# 339152                    Original Hummus        67             20
# 741065  Organic Whole Peeled Baby Carrots       123              4
# 823795               Organic Apple Slices        50             19
# 938513         Organic Chicken Drumsticks        49             12

# %%
mb = market_basket.product_name.values

# %%
mb
# Out:
# array([list(['Organic Egg Whites', 'Michigan Organic Kale', 'Garlic Powder', 'Coconut Butter', 'Natural Sweetener', 'Carrots', 'Original Unflavored Gelatine Mix', 'All Natural No Stir Creamy Almond Butter', 'Classic Blend Cole Slaw']),
#        list(['Total 2% with Strawberry Lowfat Greek Strained Yogurt', 'Unsweetened Almondmilk', 'Lemons', 'Organic Baby Spinach', 'Unsweetened Chocolate Almond Breeze Almond Milk', 'Organic Ginger Root', 'Air Chilled Organic Boneless Skinless Chicken Breasts', 'Organic Ezekiel 49 Bread Cinnamon Raisin']),
#        list(['Plain Pre-Sliced Bagels', 'Honey/Lemon Cough Drops', 'Chewy 25% Low Sugar Chocolate Chip Granola', 'Oats & Chocolate Chewy Bars', "Kellogg's Nutri-Grain Apple Cinnamon Cereal", 'Nutri-Grain Soft Baked Strawberry Cereal Breakfast Bars', "Kellogg's Nutri-Grain Blueberry Cereal", 'Tiny Twists Pretzels', 'Traditional Snack Mix', 'Goldfish Cheddar Baked Snack Crackers', 'Original Orange Juice', 'Sugarfree Energy Drink', 'Energy Drink']),
#        ...,
#        list(['Organic Shredded Mozzarella', 'Organic Chopped Spinach', 'Organic Pumpkin', 'Low Fat Strawberry Yogurt Tubes', 'Cream Top Smooth Coffee Yogurt', 'Organic Vanilla Extract', 'Liquid Hand Soap, Refill, Lemon Verbena Scent', 'Dark Chocolate Morsels', 'Certified Compostable Large Baking Cups', 'Gluten Free Baking & Packing Mix', 'Roasted Garlic Extra Virgin Olive Oil']),
#        list(['Bag of Organic Bananas', 'Organic Gala Apples', 'Apple Honeycrisp Organic', 'Almond Breeze Original Almond Milk', 'Light Semisoft Cheese']),
#        list(['Organic Baby Spinach', 'Organic Raspberries', 'Banana', 'Organic Strawberries', 'Boneless Skinless Chicken Breasts', 'No Salt Added Black Beans', 'Organic White Basmati Rice', 'Original Enriched Rice Drink', 'Organic Short Grain Brown Rice', 'Organic Broccoli Crowns', 'Oat Blueberry Lemon Whenever Bars', 'Original Bar BBQ Sauce', '80% Lean Ground Beef'])],
#       dtype=object)

# %%
newmb = []
for i in mb:
    newmb.append(i)
newmb[:5]
# Out:
# [['Organic Egg Whites',
#   'Michigan Organic Kale',
#   'Garlic Powder',
#   'Coconut Butter',
#   'Natural Sweetener',
#   'Carrots',
#   'Original Unflavored Gelatine Mix',
#   'All Natural No Stir Creamy Almond Butter',
#   'Classic Blend Cole Slaw'],
#  ['Total 2% with Strawberry Lowfat Greek Strained Yogurt',
#   'Unsweetened Almondmilk',
#   'Lemons',
#   'Organic Baby Spinach',
#   'Unsweetened Chocolate Almond Breeze Almond Milk',
#   'Organic Ginger Root',
#   'Air Chilled Organic Boneless Skinless Chicken Breasts',
#   'Organic Ezekiel 49 Bread Cinnamon Raisin'],
#  ['Plain Pre-Sliced Bagels',
#   'Honey/Lemon Cough Drops',
#   'Chewy 25% Low Sugar Chocolate Chip Granola',
#   'Oats & Chocolate Chewy Bars',
#   "Kellogg's Nutri-Grain Apple Cinnamon Cereal",
#   'Nutri-Grain Soft Baked Strawberry Cereal Breakfast Bars',
#   "Kellogg's Nutri-Grain Blueberry Cereal",
#   'Tiny Twists Pretzels',
#   'Traditional Snack Mix',
#   'Goldfish Cheddar Baked Snack Crackers',
#   'Original Orange Juice',
#   'Sugarfree Energy Drink',
#   'Energy Drink'],
#  ['Bag of Organic Bananas',
#   'Just Crisp, Parmesan',
#   'Fresh Fruit Salad',
#   'Organic Raspberries',
#   '2% Reduced Fat Milk',
#   'Sensitive Toilet Paper',
#   'Natural Artesian Water, Mini & Mobile',
#   'Matzos, Thin, Tea',
#   'Boneless Skinless Chicken Breast Fillets',
#   'Mini Original Babybel Cheese',
#   'Macaroni And Cheese',
#   'Clementines',
#   "Biscuits Orange Pim's",
#   'Dairy Milk Fruit & Nut Chocolate Bar',
#   'Artichokes',
#   'Apricot Preserves',
#   'One Ply Choose A Size Big Roll Paper Towel Rolls',
#   'Wafer, Chocolate',
#   'French Lavender Hand Wash',
#   'American Slices Cheese',
#   'Everyday  Facial Tissues',
#   'Organic Hass Avocado',
#   'Spaghetti Pasta',
#   'Meyer Lemon',
#   'Bag of Organic Lemons',
#   'Original Black Box Tablewater Cracker'],
#  ['Cleanse',
#   'Dryer Sheets Geranium Scent',
#   'Clean Day Lavender Scent Room Freshener Spray']]

# %%
list(apriori(newmb, min_support=0.00045, min_confidence=0.2, min_lift=2, min_length=2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-de56188c0335> in <module>()
# ----> 1 list(apriori(newmb, min_support=0.00045, min_confidence=0.2, min_lift=2, min_length=2))
#
# ~\Anaconda3\lib\site-packages\apyori.py in apriori(transactions, **kwargs)
#     286
#     287     # Calculate ordered stats.
# --> 288     for support_record in support_records:
#     289         ordered_statistics = list(
#     290             _filter_ordered_statistics(
#
# ~\Anaconda3\lib\site-packages\apyori.py in gen_support_records(transaction_manager, min_support, **kwargs)
#     201         if max_length and length > max_length:
#     202             break
# --> 203         candidates = _create_next_candidates(relations, length)
#     204
#     205
#
# ~\Anaconda3\lib\site-packages\apyori.py in create_next_candidates(prev_candidates, length)
#     160     # in the previous candidates.
#     161     next_candidates = [
# --> 162         candidate for candidate in tmp_next_candidates
#     163         if all(
#     164             True if frozenset(x) in prev_candidates else False
#
# ~\Anaconda3\lib\site-packages\apyori.py in <listcomp>(.0)
#     163         if all(
#     164             True if frozenset(x) in prev_candidates else False
# --> 165             for x in combinations(candidate, length - 1))
#     166     ]
#     167     return next_candidates
#
# ~\Anaconda3\lib\site-packages\apyori.py in <genexpr>(.0)
#     163         if all(
#     164             True if frozenset(x) in prev_candidates else False
# --> 165             for x in combinations(candidate, length - 1))
#     166     ]
#     167     return next_candidates
#
# KeyboardInterrupt:

# %%
ar = list(apriori(newmb, min_support=0.00045, min_confidence=0.2, min_lift=2, min_length=2))
ar = pd.DataFrame(ar)
ar
# Out:
#                                                 items   support  \
# 0   (Apple Honeycrisp Organic, Bag of Organic Bana...  0.007193
# 1          (Organic Cucumber, Bag of Organic Bananas)  0.006488
# 2     (Organic D'Anjou Pears, Bag of Organic Bananas)  0.004665
# 3       (Organic Gala Apples, Bag of Organic Bananas)  0.006589
# 4      (Organic Hass Avocado, Bag of Organic Bananas)  0.019101
# 5              (Organic Kiwi, Bag of Organic Bananas)  0.004554
# 6   (Organic Large Extra Fancy Fuji Apple, Bag of ...  0.007264
# 7             (Organic Lemon, Bag of Organic Bananas)  0.007344
# 8       (Organic Raspberries, Bag of Organic Bananas)  0.012795
# 9    (Organic Tomato Cluster, Bag of Organic Bananas)  0.004866
# 10                              (Blueberries, Banana)  0.005531
# 11        (Boneless Skinless Chicken Breasts, Banana)  0.004685
# 12                           (Cucumber Kirby, Banana)  0.009893
# 13                         (Banana, Honeycrisp Apple)  0.009007
# 14                          (Organic Avocado, Banana)  0.016593
# 15                       (Banana, Organic Fuji Apple)  0.010326
# 16                      (Seedless Red Grapes, Banana)  0.007727
# 17                          (Organic Cilantro, Limes)  0.005460
# 18           (Organic Cucumber, Organic Baby Spinach)  0.005057
# 19           (Organic Zucchini, Organic Baby Spinach)  0.006619
# 20        (Organic Strawberries, Organic Blueberries)  0.007203
# 21           (Organic Hass Avocado, Organic Cucumber)  0.005289
# 22             (Organic Garlic, Organic Yellow Onion)  0.006820
# 23              (Organic Lemon, Organic Hass Avocado)  0.006982
# 24  (Organic Large Extra Fancy Fuji Apple, Organic...  0.004785
# 25        (Organic Raspberries, Organic Strawberries)  0.010115
# 26  (Organic Whole String Cheese, Organic Strawber...  0.004604
#
#                                    ordered_statistics
# 0   [((Apple Honeycrisp Organic), (Bag of Organic ...
# 1   [((Organic Cucumber), (Bag of Organic Bananas)...
# 2   [((Organic D'Anjou Pears), (Bag of Organic Ban...
# 3   [((Organic Gala Apples), (Bag of Organic Banan...
# 4   [((Organic Hass Avocado), (Bag of Organic Bana...
# 5   [((Organic Kiwi), (Bag of Organic Bananas), 0....
# 6   [((Organic Large Extra Fancy Fuji Apple), (Bag...
# 7   [((Organic Lemon), (Bag of Organic Bananas), 0...
# 8   [((Organic Raspberries), (Bag of Organic Banan...
# 9   [((Organic Tomato Cluster), (Bag of Organic Ba...
# 10  [((Blueberries), (Banana), 0.3041551246537396,...
# 11  [((Boneless Skinless Chicken Breasts), (Banana...
# 12  [((Cucumber Kirby), (Banana), 0.32941965783294...
# 13  [((Honeycrisp Apple), (Banana), 0.356886227544...
# 14  [((Organic Avocado), (Banana), 0.3061907417735...
# 15  [((Organic Fuji Apple), (Banana), 0.3742241694...
# 16  [((Seedless Red Grapes), (Banana), 0.303042275...
# 17  [((Organic Cilantro), (Limes), 0.2562647754137...
# 18  [((Organic Cucumber), (Organic Baby Spinach), ...
# 19  [((Organic Zucchini), (Organic Baby Spinach), ...
# 20  [((Organic Blueberries), (Organic Strawberries...
# 21  [((Organic Cucumber), (Organic Hass Avocado), ...
# 22  [((Organic Garlic), (Organic Yellow Onion), 0....
# 23  [((Organic Lemon), (Organic Hass Avocado), 0.2...
# 24  [((Organic Large Extra Fancy Fuji Apple), (Org...
# 25  [((Organic Raspberries), (Organic Strawberries...
# 26  [((Organic Whole String Cheese), (Organic Stra...

# %%
ar.iloc[24,:]['items']
# Out:
# frozenset({'Organic Large Extra Fancy Fuji Apple', 'Organic Strawberries'})

# %%
market_basket[(market_basket.product_name.str.contains('Organic Garlic'))& (market_basket['product_name'].str.contains('Organic Yellow Onion'))].shape
# Out:
# (706, 2)

# %%
market_basket[(market_basket.product_name.str.contains('Organic Garlic'))].shape
# Out:
# (3741, 2)

# %%
market_basket[(market_basket.product_name.str.contains('Organic Yellow Onion'))].shape
# Out:
# (3468, 2)

# %%
market_basket.shape
# Out:
# (99260, 2)

# %%
ar.iloc[0,-1]
# Out:
# [OrderedStatistic(items_base=frozenset({'Apple Honeycrisp Organic'}), items_add=frozenset({'Bag of Organic Bananas'}), confidence=0.27199999999999996, lift=2.2751091261481413)]

# %%
import re
def conf(x):
    return re.findall(r'\d+[.]\d+',x)

# %%
ar['ordered_statistics'] = ar['ordered_statistics'].astype('str')
ar['Confidence1'] = ar.ordered_statistics.apply(conf)

# %%
ar
# Out:
#                                                 items   support  \
# 0   (Apple Honeycrisp Organic, Bag of Organic Bana...  0.007193
# 1          (Organic Cucumber, Bag of Organic Bananas)  0.006488
# 2     (Organic D'Anjou Pears, Bag of Organic Bananas)  0.004665
# 3       (Organic Gala Apples, Bag of Organic Bananas)  0.006589
# 4      (Organic Hass Avocado, Bag of Organic Bananas)  0.019101
# 5              (Organic Kiwi, Bag of Organic Bananas)  0.004554
# 6   (Organic Large Extra Fancy Fuji Apple, Bag of ...  0.007264
# 7             (Organic Lemon, Bag of Organic Bananas)  0.007344
# 8       (Organic Raspberries, Bag of Organic Bananas)  0.012795
# 9    (Organic Tomato Cluster, Bag of Organic Bananas)  0.004866
# 10                              (Blueberries, Banana)  0.005531
# 11        (Boneless Skinless Chicken Breasts, Banana)  0.004685
# 12                           (Cucumber Kirby, Banana)  0.009893
# 13                         (Banana, Honeycrisp Apple)  0.009007
# 14                          (Organic Avocado, Banana)  0.016593
# 15                       (Banana, Organic Fuji Apple)  0.010326
# 16                      (Seedless Red Grapes, Banana)  0.007727
# 17                          (Organic Cilantro, Limes)  0.005460
# 18           (Organic Cucumber, Organic Baby Spinach)  0.005057
# 19           (Organic Zucchini, Organic Baby Spinach)  0.006619
# 20        (Organic Strawberries, Organic Blueberries)  0.007203
# 21           (Organic Hass Avocado, Organic Cucumber)  0.005289
# 22             (Organic Garlic, Organic Yellow Onion)  0.006820
# 23              (Organic Lemon, Organic Hass Avocado)  0.006982
# 24  (Organic Large Extra Fancy Fuji Apple, Organic...  0.004785
# 25        (Organic Raspberries, Organic Strawberries)  0.010115
# 26  (Organic Whole String Cheese, Organic Strawber...  0.004604
#
#                                    ordered_statistics  \
# 0   [OrderedStatistic(items_base=frozenset({'Apple...
# 1   [OrderedStatistic(items_base=frozenset({'Organ...
# 2   [OrderedStatistic(items_base=frozenset({"Organ...
# 3   [OrderedStatistic(items_base=frozenset({'Organ...
# 4   [OrderedStatistic(items_base=frozenset({'Organ...
# 5   [OrderedStatistic(items_base=frozenset({'Organ...
# 6   [OrderedStatistic(items_base=frozenset({'Organ...
# 7   [OrderedStatistic(items_base=frozenset({'Organ...
# 8   [OrderedStatistic(items_base=frozenset({'Organ...
# 9   [OrderedStatistic(items_base=frozenset({'Organ...
# 10  [OrderedStatistic(items_base=frozenset({'Blueb...
# 11  [OrderedStatistic(items_base=frozenset({'Bonel...
# 12  [OrderedStatistic(items_base=frozenset({'Cucum...
# 13  [OrderedStatistic(items_base=frozenset({'Honey...
# 14  [OrderedStatistic(items_base=frozenset({'Organ...
# 15  [OrderedStatistic(items_base=frozenset({'Organ...
# 16  [OrderedStatistic(items_base=frozenset({'Seedl...
# 17  [OrderedStatistic(items_base=frozenset({'Organ...
# 18  [OrderedStatistic(items_base=frozenset({'Organ...
# 19  [OrderedStatistic(items_base=frozenset({'Organ...
# 20  [OrderedStatistic(items_base=frozenset({'Organ...
# 21  [OrderedStatistic(items_base=frozenset({'Organ...
# 22  [OrderedStatistic(items_base=frozenset({'Organ...
# 23  [OrderedStatistic(items_base=frozenset({'Organ...
# 24  [OrderedStatistic(items_base=frozenset({'Organ...
# 25  [OrderedStatistic(items_base=frozenset({'Organ...
# 26  [OrderedStatistic(items_base=frozenset({'Organ...
#
#                                   Confidence1
# 0   [0.27199999999999996, 2.2751091261481413]
# 1    [0.26232179226069247, 2.194156998381759]
# 2    [0.2949044585987261, 2.4666905334549214]
# 3      [0.279367791542076, 2.336736073857459]
# 4   [0.28942146237215693, 2.4208287145074827]
# 5     [0.2952318745917701, 2.469429162549852]
# 6   [0.31402439024390244, 2.6266167502831173]
# 7   [0.26654478976234003, 2.2294797195424176]
# 8     [0.2996696554978764, 2.506548411959148]
# 9    [0.24150000000000002, 2.019995786635207]
# 10   [0.3041551246537396, 2.0455611947374615]
# 11    [0.2996134020618557, 2.015016348577803]
# 12  [0.32941965783294197, 2.2154749804524574]
# 13    [0.3568862275449102, 2.400198316017873]
# 14   [0.3061907417735638, 2.0592515094819395]
# 15   [0.3742241694048923, 2.5168027003949867]
# 16    [0.303042275780324, 2.0380768543908774]
# 17     [0.2562647754137116, 5.89224961954251]
# 18   [0.2044806517311609, 2.7145579097010875]
# 19   [0.20252774352651046, 2.688632315426164]
# 20  [0.22909323934636336, 2.7942731552617386]
# 21   [0.21384928716904275, 3.240219851076047]
# 22   [0.20053317535545023, 5.776239984266393]
# 23  [0.25338208409506396, 3.8392162520647304]
# 24   [0.2068815331010453, 2.5233547524710933]
# 25  [0.23690420009438415, 2.8895442247933856]
# 26  [0.24756229685807152, 3.0195420970916906]

# %%
new_df = ar.copy()

# %%
new_df['items']
# Out:
# 0     (Apple Honeycrisp Organic, Bag of Organic Bana...
# 1            (Organic Cucumber, Bag of Organic Bananas)
# 2       (Organic D'Anjou Pears, Bag of Organic Bananas)
# 3         (Organic Gala Apples, Bag of Organic Bananas)
# 4        (Organic Hass Avocado, Bag of Organic Bananas)
# 5                (Organic Kiwi, Bag of Organic Bananas)
# 6     (Organic Large Extra Fancy Fuji Apple, Bag of ...
# 7               (Organic Lemon, Bag of Organic Bananas)
# 8         (Organic Raspberries, Bag of Organic Bananas)
# 9      (Organic Tomato Cluster, Bag of Organic Bananas)
# 10                                (Blueberries, Banana)
# 11          (Boneless Skinless Chicken Breasts, Banana)
# 12                             (Cucumber Kirby, Banana)
# 13                           (Banana, Honeycrisp Apple)
# 14                            (Organic Avocado, Banana)
# 15                         (Banana, Organic Fuji Apple)
# 16                        (Seedless Red Grapes, Banana)
# 17                            (Organic Cilantro, Limes)
# 18             (Organic Cucumber, Organic Baby Spinach)
# 19             (Organic Zucchini, Organic Baby Spinach)
# 20          (Organic Strawberries, Organic Blueberries)
# 21             (Organic Hass Avocado, Organic Cucumber)
# 22               (Organic Garlic, Organic Yellow Onion)
# 23                (Organic Lemon, Organic Hass Avocado)
# 24    (Organic Large Extra Fancy Fuji Apple, Organic...
# 25          (Organic Raspberries, Organic Strawberries)
# 26    (Organic Whole String Cheese, Organic Strawber...
# Name: items, dtype: object

# %%
ar['confidence'] = ar.Confidence1.apply(lambda x:x[0][:4])
ar['lift'] = ar.Confidence1.apply(lambda x:x[1][0:4])
ar.drop(['Confidence1','ordered_statistics'],inplace = True,axis = 1)
ar
# Out:
#                                                 items   support confidence  \
# 0   (Apple Honeycrisp Organic, Bag of Organic Bana...  0.007193       0.27
# 1          (Organic Cucumber, Bag of Organic Bananas)  0.006488       0.26
# 2     (Organic D'Anjou Pears, Bag of Organic Bananas)  0.004665       0.29
# 3       (Organic Gala Apples, Bag of Organic Bananas)  0.006589       0.27
# 4      (Organic Hass Avocado, Bag of Organic Bananas)  0.019101       0.28
# 5              (Organic Kiwi, Bag of Organic Bananas)  0.004554       0.29
# 6   (Organic Large Extra Fancy Fuji Apple, Bag of ...  0.007264       0.31
# 7             (Organic Lemon, Bag of Organic Bananas)  0.007344       0.26
# 8       (Organic Raspberries, Bag of Organic Bananas)  0.012795       0.29
# 9    (Organic Tomato Cluster, Bag of Organic Bananas)  0.004866       0.24
# 10                              (Blueberries, Banana)  0.005531       0.30
# 11        (Boneless Skinless Chicken Breasts, Banana)  0.004685       0.29
# 12                           (Cucumber Kirby, Banana)  0.009893       0.32
# 13                         (Banana, Honeycrisp Apple)  0.009007       0.35
# 14                          (Organic Avocado, Banana)  0.016593       0.30
# 15                       (Banana, Organic Fuji Apple)  0.010326       0.37
# 16                      (Seedless Red Grapes, Banana)  0.007727       0.30
# 17                          (Organic Cilantro, Limes)  0.005460       0.25
# 18           (Organic Cucumber, Organic Baby Spinach)  0.005057       0.20
# 19           (Organic Zucchini, Organic Baby Spinach)  0.006619       0.20
# 20        (Organic Strawberries, Organic Blueberries)  0.007203       0.22
# 21           (Organic Hass Avocado, Organic Cucumber)  0.005289       0.21
# 22             (Organic Garlic, Organic Yellow Onion)  0.006820       0.20
# 23              (Organic Lemon, Organic Hass Avocado)  0.006982       0.25
# 24  (Organic Large Extra Fancy Fuji Apple, Organic...  0.004785       0.20
# 25        (Organic Raspberries, Organic Strawberries)  0.010115       0.23
# 26  (Organic Whole String Cheese, Organic Strawber...  0.004604       0.24
#
#     lift
# 0   2.27
# 1   2.19
# 2   2.46
# 3   2.33
# 4   2.42
# 5   2.46
# 6   2.62
# 7   2.22
# 8   2.50
# 9   2.01
# 10  2.04
# 11  2.01
# 12  2.21
# 13  2.40
# 14  2.05
# 15  2.51
# 16  2.03
# 17  5.89
# 18  2.71
# 19  2.68
# 20  2.79
# 21  3.24
# 22  5.77
# 23  3.83
# 24  2.52
# 25  2.88
# 26  3.01

# %%
ar.dtypes
# Out:
# items          object
# support       float64
# confidence     object
# lift           object
# dtype: object

# %%
ar.confidence = ar.confidence.astype('float')
ar.lift = ar.lift.astype('float')
ar.sort_values('confidence',ascending = [0])
# Out:
#                                                 items   support  confidence  \
# 15                       (Banana, Organic Fuji Apple)  0.010326        0.37
# 13                         (Banana, Honeycrisp Apple)  0.009007        0.35
# 12                           (Cucumber Kirby, Banana)  0.009893        0.32
# 6   (Organic Large Extra Fancy Fuji Apple, Bag of ...  0.007264        0.31
# 16                      (Seedless Red Grapes, Banana)  0.007727        0.30
# 14                          (Organic Avocado, Banana)  0.016593        0.30
# 10                              (Blueberries, Banana)  0.005531        0.30
# 2     (Organic D'Anjou Pears, Bag of Organic Bananas)  0.004665        0.29
# 5              (Organic Kiwi, Bag of Organic Bananas)  0.004554        0.29
# 8       (Organic Raspberries, Bag of Organic Bananas)  0.012795        0.29
# 11        (Boneless Skinless Chicken Breasts, Banana)  0.004685        0.29
# 4      (Organic Hass Avocado, Bag of Organic Bananas)  0.019101        0.28
# 0   (Apple Honeycrisp Organic, Bag of Organic Bana...  0.007193        0.27
# 3       (Organic Gala Apples, Bag of Organic Bananas)  0.006589        0.27
# 1          (Organic Cucumber, Bag of Organic Bananas)  0.006488        0.26
# 7             (Organic Lemon, Bag of Organic Bananas)  0.007344        0.26
# 17                          (Organic Cilantro, Limes)  0.005460        0.25
# 23              (Organic Lemon, Organic Hass Avocado)  0.006982        0.25
# 9    (Organic Tomato Cluster, Bag of Organic Bananas)  0.004866        0.24
# 26  (Organic Whole String Cheese, Organic Strawber...  0.004604        0.24
# 25        (Organic Raspberries, Organic Strawberries)  0.010115        0.23
# 20        (Organic Strawberries, Organic Blueberries)  0.007203        0.22
# 21           (Organic Hass Avocado, Organic Cucumber)  0.005289        0.21
# 18           (Organic Cucumber, Organic Baby Spinach)  0.005057        0.20
# 19           (Organic Zucchini, Organic Baby Spinach)  0.006619        0.20
# 22             (Organic Garlic, Organic Yellow Onion)  0.006820        0.20
# 24  (Organic Large Extra Fancy Fuji Apple, Organic...  0.004785        0.20
#
#     lift
# 15  2.51
# 13  2.40
# 12  2.21
# 6   2.62
# 16  2.03
# 14  2.05
# 10  2.04
# 2   2.46
# 5   2.46
# 8   2.50
# 11  2.01
# 4   2.42
# 0   2.27
# 3   2.33
# 1   2.19
# 7   2.22
# 17  5.89
# 23  3.83
# 9   2.01
# 26  3.01
# 25  2.88
# 20  2.79
# 21  3.24
# 18  2.71
# 19  2.68
# 22  5.77
# 24  2.52

# %%
market_basket[market_basket['product_name'].str.contains('Organic Fuji Apple')].shape
# Out:
# (3066, 2)

# %%
market_basket[market_basket['product_name'].str.contains(r'Banana')].shape
# Out:
# (0, 2)

# %%
market_basket.shape
# Out:
# (99260, 2)

# %%
market_basket.head(2)
# Out:
#    order_id                                       product_name
# 0         2  [Organic Egg Whites, Michigan Organic Kale, Ga...
# 1         3  [Total 2% with Strawberry Lowfat Greek Straine...

# %%
market_basket.product_name = market_basket.product_name.astype('str')

# %%
market_basket[(market_basket.product_name.str.contains('Banana'))& (market_basket['product_name'].str.contains('Organic Fuji Apple'))].shape
# Out:
# (1583, 2)

# %%
market_basket[(market_basket.product_name.str.contains('Banana'))].shape
# Out:
# (29449, 2)

# %%
market_basket.order_id.nunique()
# Out:
# 99260

# %%
29449/99260
# Out:
# 0.2966854724964739

# %%
1583/99260
# Out:
# 0.015948015313318558

# %%
0.016/0.30
# Out:
# 0.05333333333333334

# %%
ar.shape
# Out:
# (27, 4)

# %%
ar.Confidence1[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-aacf42b66f7d> in <module>()
# ----> 1 ar.Confidence1[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Confidence1'

# %%
def conf(x):
    return x.str.split(',')[0][0].replace('[','')

# %%
ar['Confidence1'] = ar['Confidence1'].astype('str')
ar['Confidence'] = ar['Confidence1'].apply(conf)
#ar['lift'] = ar['Confidence1'].str.split(',')[0][1].replace(']','')
ar
# Out:
#                                                items   support  \
# 0  (Lime Sparkling Water, Sparkling Water Grapefr...  0.004616
# 1                          (Limes, Organic Cilantro)  0.005318
# 2           (Organic Zucchini, Organic Baby Spinach)  0.006723
# 3           (Organic Hass Avocado, Organic Cucumber)  0.005619
# 4              (Organic Hass Avocado, Organic Lemon)  0.006422
#
#                                   ordered_statistics  \
# 0  [OrderedStatistic(items_base=frozenset({'Lime ...
# 1  [OrderedStatistic(items_base=frozenset({'Organ...
# 2  [OrderedStatistic(items_base=frozenset({'Organ...
# 3  [OrderedStatistic(items_base=frozenset({'Organ...
# 4  [OrderedStatistic(items_base=frozenset({'Organ...
#
#                                      Confidence1  \
# 0   ['0.2893081761006289', '11.963673373522273']
# 1  ['0.25728155339805825', '6.1049237170596395']
# 2   ['0.2302405498281787', '3.1780849301767717']
# 3  ['0.22764227642276422', '3.5448170731707314']
# 4               ['0.23272727272727273', '3.624']
#
#                                   Confidence                   lift
# 0   [0.2893081761006289, 11.963673373522273]   '11.963673373522273'
# 1  [0.25728155339805825, 6.1049237170596395]   '11.963673373522273'
# 2   [0.2302405498281787, 3.1780849301767717]   '11.963673373522273'
# 3  [0.22764227642276422, 3.5448170731707314]   '11.963673373522273'
# 4               [0.23272727272727273, 3.624]   '11.963673373522273'

# %%
def conf2(x):
    return x[0][0]

# %%
ar['Confidence2'] = ar['Confidence'].apply(conf)

# %%
ar
# Out:
#                                                items   support  \
# 0  (Lime Sparkling Water, Sparkling Water Grapefr...  0.004616
# 1                          (Limes, Organic Cilantro)  0.005318
# 2           (Organic Zucchini, Organic Baby Spinach)  0.006723
# 3           (Organic Hass Avocado, Organic Cucumber)  0.005619
# 4              (Organic Hass Avocado, Organic Lemon)  0.006422
#
#                                   ordered_statistics  \
# 0  [OrderedStatistic(items_base=frozenset({'Lime ...
# 1  [OrderedStatistic(items_base=frozenset({'Organ...
# 2  [OrderedStatistic(items_base=frozenset({'Organ...
# 3  [OrderedStatistic(items_base=frozenset({'Organ...
# 4  [OrderedStatistic(items_base=frozenset({'Organ...
#
#                                      Confidence1  \
# 0   ['0.2893081761006289', '11.963673373522273']
# 1  ['0.25728155339805825', '6.1049237170596395']
# 2   ['0.2302405498281787', '3.1780849301767717']
# 3  ['0.22764227642276422', '3.5448170731707314']
# 4               ['0.23272727272727273', '3.624']
#
#                                   Confidence                   lift  \
# 0   [0.2893081761006289, 11.963673373522273]   '11.963673373522273'
# 1  [0.25728155339805825, 6.1049237170596395]   '11.963673373522273'
# 2   [0.2302405498281787, 3.1780849301767717]   '11.963673373522273'
# 3  [0.22764227642276422, 3.5448170731707314]   '11.963673373522273'
# 4               [0.23272727272727273, 3.624]   '11.963673373522273'
#
#                                  Confidence2
# 0   [0.2893081761006289, 11.963673373522273]
# 1  [0.25728155339805825, 6.1049237170596395]
# 2   [0.2302405498281787, 3.1780849301767717]
# 3  [0.22764227642276422, 3.5448170731707314]
# 4               [0.23272727272727273, 3.624]

# %%
ar['Confidence']
# Out:
# ['0.2893081761006289', '11.963673373522273']

# %%
"'0.2893081761006289', '11.963673373522273'".split(',')
# Out:
# ["'0.2893081761006289'", " '11.963673373522273'"]

# %%
int("'0.2893081761006289'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-344a9e4ee5d9> in <module>()
# ----> 1 int("'0.2893081761006289'")
#
# ValueError: invalid literal for int() with base 10: "'0.2893081761006289'"
